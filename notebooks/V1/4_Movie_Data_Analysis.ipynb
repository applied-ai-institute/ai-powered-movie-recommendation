# %% [markdown]
# # Notebook 4: MovieLens Data Analysis
#
# ## Learning Objectives
# - Load and analyze MovieLens movie dataset
# - Parse multi-genre movie data
# - Count movies by genre
# - Create visualizations
# - Export results to Excel
#
# ## What's New:
# - **Pure Data Analysis** - No LLM needed!
# - **MovieLens Dataset** - Real movie data with genres
# - **Genre Analysis** - Count movies per genre
# - **Excel Export** - Professional output tables
# - **Visualizations** - Charts and graphs
#
# ## Dataset:
# - **File**: `movies.csv` from MovieLens dataset
# - **Location**: `data/movie_lens/movies.csv`
# - **Columns**: movieId, title, genres
# - **Genre Format**: Pipe-separated (e.g., "Action|Adventure|Thriller")
#
# ## No API Keys Required!
# This notebook uses only Pandas, Matplotlib, and Excel export.

# %% [markdown]
# ## Step 1: Install Required Packages

# %%
# %pip install pandas matplotlib seaborn openpyxl --quiet

print("✓ Packages installed")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ✓ Packages installed

# %% [markdown]
# ## Step 2: Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path

# Set visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

print("✓ Libraries imported")
# Out:
# ✓ Libraries imported

# %% [markdown]
# ## Step 3: Load MovieLens Data
#
# **USER INPUT**: Specify the path to your movies.csv file.

# %%
# ============================================================================
# USER INPUT: Specify movies.csv file path
# ============================================================================
movies_file = "../data/movie_lens/movies.csv"  # ← CHANGE THIS PATH

# Check if file exists
if os.path.exists(movies_file):
    print(f"✓ File found: {movies_file}")
else:
    print(f"❌ File not found: {movies_file}")
    print(f"Current directory: {os.getcwd()}")
    print("\nPlease update the path to your movies.csv file")
# Out:
# ✓ File found: ../data/movie_lens/movies.csv

# %% [markdown]
# ## Step 4: Load and Explore the Data

# %%
# Load the CSV file
movies_df = pd.read_csv(movies_file)

print("=" * 70)
print("MOVIELENS DATASET LOADED")
print("=" * 70)
print(f"\nTotal movies: {len(movies_df):,}")
print(f"Columns: {', '.join(movies_df.columns)}")

print(f"\n{'='*70}")
print("FIRST 10 MOVIES")
print("=" * 70)
display(movies_df.head(10))
# Out:
# ...
# MOVIELENS DATASET LOADED
# ...
#
# Total movies: 9,742
# Columns: movieId, title, genres
#
# ...
# FIRST 10 MOVIES
# ...
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# ...

# %% [markdown]
# ## Step 5: Understand the Genre Format

# %%
# Show some examples of the genre format
print("=" * 70)
print("GENRE FORMAT EXAMPLES")
print("=" * 70)

sample_movies = movies_df.head(10)[['title', 'genres']]
for idx, row in sample_movies.iterrows():
    print(f"\n{row['title']}")
    print(f"  Genres: {row['genres']}")
    print(f"  Split: {row['genres'].split('|')}")
# Out:
# ...
# GENRE FORMAT EXAMPLES
# ...
#
# Toy Story (1995)
#   Genres: Adventure|Animation|Children|Comedy|Fantasy
#   Split: ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy']
#
# Jumanji (1995)
#   Genres: Adventure|Children|Fantasy
#   Split: ['Adventure', 'Children', 'Fantasy']
#
# Grumpier Old Men (1995)
#   Genres: Comedy|Romance
#   Split: ['Comedy', 'Romance']
#
# Waiting to Exhale (1995)
#   Genres: Comedy|Drama|Romance
#   Split: ['Comedy', 'Drama', 'Romance']
#
# Father of the Bride Part II (1995)
#   Genres: Comedy
#   Split: ['Comedy']
#
# Heat (1995)
#   Genres: Action|Crime|Thriller
#   Split: ['Action', 'Crime', 'Thriller']
#
# Sabrina (1995)
#   Genres: Comedy|Romance
#   Split: ['Comedy', 'Romance']
#
# Tom and Huck (1995)
#   Genres: Adventure|Children
#   Split: ['Adventure', 'Children']
#
# Sudden Death (1995)
#   Genres: Action
#   Split: ['Action']
#
# GoldenEye (1995)
#   Genres: Action|Adventure|Thriller
#   Split: ['Action', 'Adventure', 'Thriller']

# %% [markdown]
# ## Step 6: Parse and Count Genres
#
# Extract individual genres from the pipe-separated format and count occurrences.

# %%
# Parse genres and count
print("\n" + "=" * 70)
print("PARSING GENRES FROM ALL MOVIES")
print("=" * 70)

# Create a list to store all individual genres
all_genres = []

# Iterate through each movie
for genres_str in movies_df['genres']:
    # Split the pipe-separated genres
    genres_list = genres_str.split('|')
    # Add each genre to our list
    all_genres.extend(genres_list)

# Count occurrences of each genre
genre_counts = pd.Series(all_genres).value_counts()

print(f"\n✓ Parsed {len(all_genres):,} total genre tags")
print(f"✓ Found {len(genre_counts)} unique genres")

print(f"\n{'='*70}")
print("TOP 10 GENRES BY MOVIE COUNT")
print("=" * 70)
print(genre_counts.head(10))
# Out:
# ...
# PARSING GENRES FROM ALL MOVIES
# ...
#
# ✓ Parsed 22,084 total genre tags
# ✓ Found 20 unique genres
#
# ...
# TOP 10 GENRES BY MOVIE COUNT
# ...
# Drama        4361
# Comedy       3756
# Thriller     1894
# Action       1828
# Romance      1596
# Adventure    1263
# Crime        1199
# Sci-Fi        980
# Horror        978
# Fantasy       779
# Name: count, dtype: int64

# %% [markdown]
# ## Step 7: Create Genre Count Table

# %%
# Create a clean DataFrame with genre counts
genre_table = pd.DataFrame({
    'Genre': genre_counts.index,
    'Movie Count': genre_counts.values
})

print("\n" + "=" * 70)
print("COMPLETE GENRE COUNT TABLE")
print("=" * 70)
display(genre_table)

print(f"\nTotal unique genres: {len(genre_table)}")
# Out:
# ...
# COMPLETE GENRE COUNT TABLE
# ...
#                  Genre  Movie Count
# 0                Drama         4361
# 1               Comedy         3756
# 2             Thriller         1894
# 3               Action         1828
# 4              Romance         1596
# 5            Adventure         1263
# 6                Crime         1199
# 7               Sci-Fi          980
# 8               Horror          978
# 9              Fantasy          779
# 10            Children          664
# 11           Animation          611
# 12             Mystery          573
# 13         Documentary          440
# 14                 War          382
# 15             Musical          334
# 16             Western          167
# 17                IMAX          158
# 18           Film-Noir           87
# 19  (no genres listed)           34
# Total unique genres: 20

# %% [markdown]
# ## Step 8: Export to Excel
#
# Create a professional Excel file with the genre counts.

# %%
# Create output directory if it doesn't exist
output_dir = "outputs"
os.makedirs(output_dir, exist_ok=True)

# Export to Excel
excel_file = os.path.join(output_dir, "genre_counts.xlsx")

# Create Excel writer with formatting
with pd.ExcelWriter(excel_file, engine='openpyxl') as writer:
    # Write the genre counts
    genre_table.to_excel(writer, sheet_name='Genre Counts', index=False)
    
    # Get the worksheet
    worksheet = writer.sheets['Genre Counts']
    
    # Adjust column widths
    worksheet.column_dimensions['A'].width = 25  # Genre column
    worksheet.column_dimensions['B'].width = 15  # Movie Count column

print(f"\n✅ Excel file created: {excel_file}")
print(f"   Sheets: Genre Counts")
print(f"   Rows: {len(genre_table) + 1} (including header)")
# Out:
# ✅ Excel file created: outputs/genre_counts.xlsx
#    Sheets: Genre Counts
#    Rows: 21 (including header)

# %% [markdown]
# ## Step 9: Create Summary Statistics
#
# Calculate additional insights about the genre distribution.

# %%
# Summary statistics
print("\n" + "=" * 70)
print("GENRE DISTRIBUTION STATISTICS")
print("=" * 70)

summary_stats = {
    'Total Movies': len(movies_df),
    'Total Genre Tags': len(all_genres),
    'Unique Genres': len(genre_counts),
    'Most Common Genre': genre_counts.index[0],
    'Most Common Count': genre_counts.values[0],
    'Least Common Genre': genre_counts.index[-1],
    'Least Common Count': genre_counts.values[-1],
    'Average Tags per Movie': len(all_genres) / len(movies_df),
    'Median Movie Count per Genre': genre_counts.median()
}

for key, value in summary_stats.items():
    if isinstance(value, float):
        print(f"{key:.<40} {value:.2f}")
    else:
        print(f"{key:.<40} {value}")
# Out:
# ...
# GENRE DISTRIBUTION STATISTICS
# ...
# Total Movies............................ 9742
# Total Genre Tags........................ 22084
# Unique Genres........................... 20
# Most Common Genre....................... Drama
# Most Common Count....................... 4361
# Least Common Genre...................... (no genres listed)
# Least Common Count...................... 34
# Average Tags per Movie.................. 2.27
# Median Movie Count per Genre............ 721.50

# %% [markdown]
# ## Step 10: Visualize Genre Distribution
#
# Create a bar chart showing the top genres.

# %%
# Create bar chart for top 15 genres
plt.figure(figsize=(14, 8))

top_n = 15
top_genres = genre_table.head(top_n)

plt.barh(range(len(top_genres)), top_genres['Movie Count'], color='skyblue', edgecolor='navy')
plt.yticks(range(len(top_genres)), top_genres['Genre'])
plt.xlabel('Number of Movies', fontsize=12, fontweight='bold')
plt.ylabel('Genre', fontsize=12, fontweight='bold')
plt.title(f'Top {top_n} Movie Genres by Count', fontsize=14, fontweight='bold', pad=20)
plt.gca().invert_yaxis()  # Highest at top

# Add value labels on bars
for i, (idx, row) in enumerate(top_genres.iterrows()):
    plt.text(row['Movie Count'] + 50, i, f"{row['Movie Count']:,}", 
             va='center', fontsize=10)

plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'top_genres_bar.png'), dpi=300, bbox_inches='tight')
plt.show()

print(f"\n✅ Chart saved: {os.path.join(output_dir, 'top_genres_bar.png')}")
# Out:
# ✅ Chart saved: outputs/top_genres_bar.png

# %% [markdown]
# ## Step 11: Create Pie Chart for Top Genres

# %%
# Create pie chart for top 10 genres
plt.figure(figsize=(12, 8))

top_10_genres = genre_table.head(10)

colors = plt.cm.Set3(range(len(top_10_genres)))
plt.pie(top_10_genres['Movie Count'], 
        labels=top_10_genres['Genre'],
        autopct='%1.1f%%',
        colors=colors,
        startangle=90)

plt.title('Top 10 Genres - Distribution', fontsize=14, fontweight='bold', pad=20)
plt.axis('equal')

plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'top_genres_pie.png'), dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Chart saved: {os.path.join(output_dir, 'top_genres_pie.png')}")
# Out:
# ✅ Chart saved: outputs/top_genres_pie.png

# %% [markdown]
# ## Step 12: Analyze Multi-Genre Movies
#
# Find movies with multiple genres.

# %%
# Count genres per movie
movies_df['genre_count'] = movies_df['genres'].apply(lambda x: len(x.split('|')))

print("\n" + "=" * 70)
print("MULTI-GENRE ANALYSIS")
print("=" * 70)

genre_count_dist = movies_df['genre_count'].value_counts().sort_index()

print(f"\nDistribution of genre count per movie:")
for count, num_movies in genre_count_dist.items():
    print(f"  {count} genre(s): {num_movies:,} movies")

print(f"\nAverage genres per movie: {movies_df['genre_count'].mean():.2f}")
print(f"Most genres in a single movie: {movies_df['genre_count'].max()}")

# Show examples of movies with most genres
max_genres = movies_df['genre_count'].max()
print(f"\n{'='*70}")
print(f"MOVIES WITH {max_genres} GENRES")
print("=" * 70)

multi_genre_movies = movies_df[movies_df['genre_count'] == max_genres][['title', 'genres']].head(5)
display(multi_genre_movies)
# Out:
# ...
# MULTI-GENRE ANALYSIS
# ...
#
# Distribution of genre count per movie:
#   1 genre(s): 2,851 movies
#   2 genre(s): 3,218 movies
#   3 genre(s): 2,338 movies
#   4 genre(s): 987 movies
#   5 genre(s): 271 movies
#   6 genre(s): 63 movies
#   7 genre(s): 12 movies
#   8 genre(s): 1 movies
#   10 genre(s): 1 movies
#
# Average genres per movie: 2.27
# Most genres in a single movie: 10
#
# ...
# MOVIES WITH 10 GENRES
# ...
#               title                                             genres
# 7441  Rubber (2010)  Action|Adventure|Comedy|Crime|Drama|Film-Noir|...

# %% [markdown]
# ## Step 13: Create Comprehensive Excel Report
#
# Export all analysis results to a multi-sheet Excel file.

# %%
# Create comprehensive Excel report
excel_report = os.path.join(output_dir, "movielens_genre_analysis.xlsx")

with pd.ExcelWriter(excel_report, engine='openpyxl') as writer:
    # Sheet 1: Genre Counts (sorted by count)
    genre_table.to_excel(writer, sheet_name='Genre Counts', index=False)
    
    # Sheet 2: Summary Statistics
    summary_df = pd.DataFrame({
        'Metric': list(summary_stats.keys()),
        'Value': list(summary_stats.values())
    })
    summary_df.to_excel(writer, sheet_name='Summary Statistics', index=False)
    
    # Sheet 3: Genre Distribution per Movie
    genre_dist_df = pd.DataFrame({
        'Number of Genres': genre_count_dist.index,
        'Number of Movies': genre_count_dist.values
    })
    genre_dist_df.to_excel(writer, sheet_name='Genres per Movie', index=False)
    
    # Sheet 4: Sample Movies (first 100)
    movies_df.head(100).to_excel(writer, sheet_name='Sample Movies', index=False)
    
    # Adjust column widths for all sheets
    for sheet_name in writer.sheets:
        worksheet = writer.sheets[sheet_name]
        for column in worksheet.columns:
            max_length = 0
            column_letter = column[0].column_letter
            for cell in column:
                try:
                    if len(str(cell.value)) > max_length:
                        max_length = len(cell.value)
                except:
                    pass
            adjusted_width = min(max_length + 2, 50)
            worksheet.column_dimensions[column_letter].width = adjusted_width

print(f"\n✅ Comprehensive Excel report created: {excel_report}")
print(f"   Sheets included:")
print(f"   1. Genre Counts - All {len(genre_table)} genres with counts")
print(f"   2. Summary Statistics - Key metrics")
print(f"   3. Genres per Movie - Distribution analysis")
print(f"   4. Sample Movies - First 100 movies from dataset")
# Out:
# ✅ Comprehensive Excel report created: outputs/movielens_genre_analysis.xlsx
#    Sheets included:
#    1. Genre Counts - All 20 genres with counts
#    2. Summary Statistics - Key metrics
#    3. Genres per Movie - Distribution analysis
#    4. Sample Movies - First 100 movies from dataset

# %% [markdown]
# ## Step 14: Display Final Summary

# %%
print("\n" + "=" * 70)
print("ANALYSIS COMPLETE!")
print("=" * 70)

print(f"\n📊 Dataset Summary:")
print(f"  Total movies analyzed: {len(movies_df):,}")
print(f"  Total genre tags: {len(all_genres):,}")
print(f"  Unique genres found: {len(genre_counts)}")
print(f"  Average genres per movie: {movies_df['genre_count'].mean():.2f}")

print(f"\n📁 Files Created:")
print(f"  1. {excel_file}")
print(f"  2. {excel_report}")
print(f"  3. {os.path.join(output_dir, 'top_genres_bar.png')}")
print(f"  4. {os.path.join(output_dir, 'top_genres_pie.png')}")

print(f"\n🎯 Top 5 Genres:")
for idx, row in genre_table.head(5).iterrows():
    print(f"  {idx+1}. {row['Genre']}: {row['Movie Count']:,} movies")

print(f"\n✅ All analysis results saved in: {output_dir}/")
# Out:
# ...
# ANALYSIS COMPLETE!
# ...
#
# 📊 Dataset Summary:
#   Total movies analyzed: 9,742
#   Total genre tags: 22,084
#   Unique genres found: 20
#   Average genres per movie: 2.27
#
# 📁 Files Created:
#   1. outputs/genre_counts.xlsx
#   2. outputs/movielens_genre_analysis.xlsx
#   3. outputs/top_genres_bar.png
#   4. outputs/top_genres_pie.png
#
# 🎯 Top 5 Genres:
#   1. Drama: 4,361 movies
#   2. Comedy: 3,756 movies
#   3. Thriller: 1,894 movies
#   4. Action: 1,828 movies
#   5. Romance: 1,596 movies
#
# ✅ All analysis results saved in: outputs/

# %% [markdown]
# ## Summary
#
# ### What We Analyzed:
# ✅ Loaded MovieLens movies.csv dataset
# ✅ Parsed pipe-separated genre data
# ✅ Counted movies by genre
# ✅ Created Excel tables with genre counts
# ✅ Generated visualizations (bar chart, pie chart)
# ✅ Analyzed multi-genre movies
# ✅ Exported comprehensive Excel report
#
# ### Output Files:
# 1. **genre_counts.xlsx** - Simple genre count table
# 2. **movielens_genre_analysis.xlsx** - Comprehensive report with:
#    - Genre Counts sheet
#    - Summary Statistics sheet
#    - Genres per Movie distribution
#    - Sample Movies dataset
# 3. **top_genres_bar.png** - Bar chart of top 15 genres
# 4. **top_genres_pie.png** - Pie chart of top 10 genres
#
# ### Key Insights:
# - Total movies in dataset
# - Number of unique genres
# - Most/least common genres
# - Average genres per movie
# - Movies with most genres
#
# ### No LLM Required!
# This notebook demonstrates pure data analysis with:
# - **Pandas** - Data manipulation
# - **Matplotlib** - Visualizations
# - **Seaborn** - Enhanced styling
# - **OpenPyXL** - Excel export
#
# ### Next Steps:
# **Notebook 5**: Add RAG capability with PDF documents
# **Notebook 6**: Add TAG capability with genre taxonomy
# **Notebook 7**: Combine all capabilities (RAG + TAG)
#
# ### Experiments to Try:
# 1. Analyze genre combinations (which genres appear together)
# 2. Find rare genre combinations
# 3. Create time-series analysis if year data available
# 4. Build genre recommendation matrix
# 5. Identify genre trends over decades
