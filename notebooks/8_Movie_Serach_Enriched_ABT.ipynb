# %% [markdown]
# # Notebook 8: Enriched Movie ABT creation and Agentic Search
#
# ## Features:
# - ✅ Start with movie ABT which has TMDB ids included with the movie
# - ✅ Test TMDB API on sample movie
# - ✅ Batch load TMDB Movie Data
# - ✅ Save enriched Movie ABT
# - ✅ Query Movie ABT using an Agent
#
# ## What's New in This Update:
# - **fetch_TMDB** tool - Can now fetch any movie using TMDB API
# - Perfect for ad-hoc queries about specific movie pages
# - Works with TMDB, or any movie database URL
#
# ## Tools Available:
# 1. **search_web** - General web search (SERPER API)
# 2. **curated_knowledge_search** - Search pre-loaded data from Excel
# 3. **fetch_url_content** - Fetch any specific URL on-demand (NEW!)

# %% [markdown]
# ## Installation

# %%
# %pip install langchain langchain-community langgraph python-dotenv openpyxl pandas langchain-openai google-search-results faiss-cpu --quiet

print("✓ Packages installed")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ✓ Packages installed

# %% [markdown]
# ## Imports

# %%
import os, json
import pandas as pd
import time
import requests
import glob

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.messages import HumanMessage, SystemMessage
from langchain.tools import tool
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langgraph.graph import StateGraph, END, MessagesState
from langgraph.prebuilt import ToolNode
from langgraph.checkpoint.memory import MemorySaver

from ai_course_utils import load_llm_from_env, load_use_case_config, display_config
from IPython.display import Image, display



print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %% [markdown]
# # Get TMDB API Key
# You can get a TMDB API key.  Here is the process: https://developer.themoviedb.org/docs/getting-started
# Set up your TMDB Key in .env file and load it into this notebook

# %%
# Load environment
load_dotenv()
TMDB_API_KEY = os.getenv("TMDB_API_KEY")  # or hardcode for testing

# %% [markdown]
# # Test TMDB API
#
# Function load_tmdb_data uses TMDB key to get TMDB data on specific id
# TMDB ids are already included in your ABT
# You can use one id to test your API as shown below

# %%
# Load TMDB Data 

def load_tmdb_data(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}"
    params = {"api_key": TMDB_API_KEY}
    response = requests.get(url, params=params)
    return response.json()

# %%
movie_id = 862
movie_json = load_tmdb_data(movie_id)
print(json.dumps(movie_json, indent = 2))
poster_path = movie_json['poster_path']
poster_url = f"https://image.tmdb.org/t/p/w500{poster_path}"
display(Image(url=poster_url))
# Out:
# {
#   "adult": false,
#   "backdrop_path": "/bSoOThXLrbgtphS2eZjwy2xYwVt.jpg",
#   "belongs_to_collection": {
#     "id": 10194,
#     "name": "Toy Story Collection",
#     "poster_path": "/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg",
#     "backdrop_path": "/hApclyB9NEZEQujAVajzi5iWE4a.jpg"
#   },
#   "budget": 30000000,
#   "genres": [
#     {
#       "id": 10751,
#       "name": "Family"
#     },
#     {
#       "id": 35,
#       "name": "Comedy"
#     },
#     {
#       "id": 16,
#       "name": "Animation"
#     },
#     {
#       "id": 12,
#       "name": "Adventure"
#     }
#   ],
#   "homepage": "http://toystory.disney.com/toy-story",
#   "id": 862,
#   "imdb_id": "tt0114709",
#   "origin_country": [
#     "US"
#   ],
#   "original_language": "en",
#   "original_title": "Toy Story",
#   "overview": "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.",
#   "popularity": 14.8637,
#   "poster_path": "/uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg",
#   "production_companies": [
#     {
#       "id": 3,
#       "logo_path": "/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png",
#       "name": "Pixar",
#       "origin_country": "US"
#     }
#   ],
#   "production_countries": [
#     {
#       "iso_3166_1": "US",
#       "name": "United States of America"
#     }
#   ],
#   "release_date": "1995-11-22",
#   "revenue": 401157969,
#   "runtime": 81,
#   "spoken_languages": [
#     {
#       "english_name": "English",
#       "iso_639_1": "en",
#       "name": "English"
#     }
#   ],
#   "status": "Released",
#   "tagline": "The adventure takes off when toys come to life!",
#   "title": "Toy Story",
#   "video": false,
#   "vote_average": 7.97,
#   "vote_count": 19556
# }
# <img src="https://image.tmdb.org/t/p/w500/uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg"/>

# %% [markdown]
# # Load ABT and add TMDB data using batches
# It is easier to view your progress by converting ABT to a list of JSONs and running the update for each JSON
# Advanced Python programmers can use Pandas directly or use multi-threading in pySpark for bulk upload

# %%
df_movie_abt = pd.read_csv("../data/outputs/analytics_base_table.csv")
df_movie_abt
# Out:
#       Unnamed: 0  movieId                                      title  \
# 0              0        1                           Toy Story (1995)
# 1              1        2                             Jumanji (1995)
# 2              2        3                    Grumpier Old Men (1995)
# 3              3        4                   Waiting to Exhale (1995)
# 4              4        5         Father of the Bride Part II (1995)
# ...          ...      ...                                        ...
# 9737        9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738        9738   193583               No Game No Life: Zero (2017)
# 9739        9739   193585                               Flint (2017)
# 9740        9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741        9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                  movielens_genres  avg_rating  \
# 0     Adventure|Animation|Children|Comedy|Fantasy    3.920930
# 1                      Adventure|Children|Fantasy    3.431818
# 2                                  Comedy|Romance    3.259615
# 3                            Comedy|Drama|Romance    2.357143
# 4                                          Comedy    3.071429
# ...                                           ...         ...
# 9737              Action|Animation|Comedy|Fantasy    4.000000
# 9738                     Animation|Comedy|Fantasy    3.500000
# 9739                                        Drama    3.500000
# 9740                             Action|Animation    3.500000
# 9741                                       Comedy    4.000000
#
#       number_of_viewers   imdbId    tmdbId
# 0                 215.0   114709     862.0
# 1                 110.0   113497    8844.0
# 2                  52.0   113228   15602.0
# 3                   7.0   114885   31357.0
# 4                  49.0   113041   11862.0
# ...                 ...      ...       ...
# 9737                1.0  5476944  432131.0
# 9738                1.0  5914996  445030.0
# 9739                1.0  6397426  479308.0
# 9740                1.0  8391976  483455.0
# 9741                1.0   101726   37891.0
#
# [9742 rows x 8 columns]

# %%
# Convert to JSON
movie_abt_json = df_movie_abt.to_dict(orient="records")
movie_abt_json
# Out:
# [{'Unnamed: 0': 0,
#   'movieId': 1,
#   'title': 'Toy Story (1995)',
#   'movielens_genres': 'Adventure|Animation|Children|Comedy|Fantasy',
#   'avg_rating': 3.92093023255814,
#   'number_of_viewers': 215.0,
#   'imdbId': 114709,
#   'tmdbId': 862.0},
#  {'Unnamed: 0': 1,
#   'movieId': 2,
#   'title': 'Jumanji (1995)',
#   'movielens_genres': 'Adventure|Children|Fantasy',
#   'avg_rating': 3.4318181818181817,
#   'number_of_viewers': 110.0,
#   'imdbId': 113497,
#   'tmdbId': 8844.0},
#  {'Unnamed: 0': 2,
#   'movieId': 3,
#   'title': 'Grumpier Old Men (1995)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.2596153846153846,
#   'number_of_viewers': 52.0,
#   'imdbId': 113228,
#   'tmdbId': 15602.0},
#  {'Unnamed: 0': 3,
#   'movieId': 4,
#   'title': 'Waiting to Exhale (1995)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 2.357142857142857,
#   'number_of_viewers': 7.0,
#   'imdbId': 114885,
#   'tmdbId': 31357.0},
#  {'Unnamed: 0': 4,
#   'movieId': 5,
#   'title': 'Father of the Bride Part II (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.0714285714285716,
#   'number_of_viewers': 49.0,
#   'imdbId': 113041,
#   'tmdbId': 11862.0},
#  {'Unnamed: 0': 5,
#   'movieId': 6,
#   'title': 'Heat (1995)',
#   'movielens_genres': 'Action|Crime|Thriller',
#   'avg_rating': 3.946078431372549,
#   'number_of_viewers': 102.0,
#   'imdbId': 113277,
#   'tmdbId': 949.0},
#  {'Unnamed: 0': 6,
#   'movieId': 7,
#   'title': 'Sabrina (1995)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.185185185185185,
#   'number_of_viewers': 54.0,
#   'imdbId': 114319,
#   'tmdbId': 11860.0},
#  {'Unnamed: 0': 7,
#   'movieId': 8,
#   'title': 'Tom and Huck (1995)',
#   'movielens_genres': 'Adventure|Children',
#   'avg_rating': 2.875,
#   'number_of_viewers': 8.0,
#   'imdbId': 112302,
#   'tmdbId': 45325.0},
#  {'Unnamed: 0': 8,
#   'movieId': 9,
#   'title': 'Sudden Death (1995)',
#   'movielens_genres': 'Action',
#   'avg_rating': 3.125,
#   'number_of_viewers': 16.0,
#   'imdbId': 114576,
#   'tmdbId': 9091.0},
#  {'Unnamed: 0': 9,
#   'movieId': 10,
#   'title': 'GoldenEye (1995)',
#   'movielens_genres': 'Action|Adventure|Thriller',
#   'avg_rating': 3.496212121212121,
#   'number_of_viewers': 132.0,
#   'imdbId': 113189,
#   'tmdbId': 710.0},
#  {'Unnamed: 0': 10,
#   'movieId': 11,
#   'title': 'American President, The (1995)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 3.6714285714285713,
#   'number_of_viewers': 70.0,
#   'imdbId': 112346,
#   'tmdbId': 9087.0},
#  {'Unnamed: 0': 11,
#   'movieId': 12,
#   'title': 'Dracula: Dead and Loving It (1995)',
#   'movielens_genres': 'Comedy|Horror',
#   'avg_rating': 2.4210526315789473,
#   'number_of_viewers': 19.0,
#   'imdbId': 112896,
#   'tmdbId': 12110.0},
#  {'Unnamed: 0': 12,
#   'movieId': 13,
#   'title': 'Balto (1995)',
#   'movielens_genres': 'Adventure|Animation|Children',
#   'avg_rating': 3.125,
#   'number_of_viewers': 8.0,
#   'imdbId': 112453,
#   'tmdbId': 21032.0},
#  {'Unnamed: 0': 13,
#   'movieId': 14,
#   'title': 'Nixon (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.8333333333333335,
#   'number_of_viewers': 18.0,
#   'imdbId': 113987,
#   'tmdbId': 10858.0},
#  {'Unnamed: 0': 14,
#   'movieId': 15,
#   'title': 'Cutthroat Island (1995)',
#   'movielens_genres': 'Action|Adventure|Romance',
#   'avg_rating': 3.0,
#   'number_of_viewers': 13.0,
#   'imdbId': 112760,
#   'tmdbId': 1408.0},
#  {'Unnamed: 0': 15,
#   'movieId': 16,
#   'title': 'Casino (1995)',
#   'movielens_genres': 'Crime|Drama',
#   'avg_rating': 3.926829268292683,
#   'number_of_viewers': 82.0,
#   'imdbId': 112641,
#   'tmdbId': 524.0},
#  {'Unnamed: 0': 16,
#   'movieId': 17,
#   'title': 'Sense and Sensibility (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.776119402985074,
#   'number_of_viewers': 67.0,
#   'imdbId': 114388,
#   'tmdbId': 4584.0},
#  {'Unnamed: 0': 17,
#   'movieId': 18,
#   'title': 'Four Rooms (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.7,
#   'number_of_viewers': 20.0,
#   'imdbId': 113101,
#   'tmdbId': 5.0},
#  {'Unnamed: 0': 18,
#   'movieId': 19,
#   'title': 'Ace Ventura: When Nature Calls (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.727272727272727,
#   'number_of_viewers': 88.0,
#   'imdbId': 112281,
#   'tmdbId': 9273.0},
#  {'Unnamed: 0': 19,
#   'movieId': 20,
#   'title': 'Money Train (1995)',
#   'movielens_genres': 'Action|Comedy|Crime|Drama|Thriller',
#   'avg_rating': 2.5,
#   'number_of_viewers': 15.0,
#   'imdbId': 113845,
#   'tmdbId': 11517.0},
#  {'Unnamed: 0': 20,
#   'movieId': 21,
#   'title': 'Get Shorty (1995)',
#   'movielens_genres': 'Comedy|Crime|Thriller',
#   'avg_rating': 3.494382022,
#   'number_of_viewers': 89.0,
#   'imdbId': 113161,
#   'tmdbId': 8012.0},
#  {'Unnamed: 0': 21,
#   'movieId': 22,
#   'title': 'Copycat (1995)',
#   'movielens_genres': 'Crime|Drama|Horror|Mystery|Thriller',
#   'avg_rating': 3.2222222222222223,
#   'number_of_viewers': 36.0,
#   'imdbId': 112722,
#   'tmdbId': 1710.0},
#  {'Unnamed: 0': 22,
#   'movieId': 23,
#   'title': 'Assassins (1995)',
#   'movielens_genres': 'Action|Crime|Thriller',
#   'avg_rating': 3.125,
#   'number_of_viewers': 16.0,
#   'imdbId': 112401,
#   'tmdbId': 9691.0},
#  {'Unnamed: 0': 23,
#   'movieId': 24,
#   'title': 'Powder (1995)',
#   'movielens_genres': 'Drama|Sci-Fi',
#   'avg_rating': 3.125,
#   'number_of_viewers': 28.0,
#   'imdbId': 114168,
#   'tmdbId': 12665.0},
#  {'Unnamed: 0': 24,
#   'movieId': 25,
#   'title': 'Leaving Las Vegas (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.625,
#   'number_of_viewers': 76.0,
#   'imdbId': 113627,
#   'tmdbId': 451.0},
#  {'Unnamed: 0': 25,
#   'movieId': 26,
#   'title': 'Othello (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.5,
#   'number_of_viewers': 13.0,
#   'imdbId': 114057,
#   'tmdbId': 16420.0},
#  {'Unnamed: 0': 26,
#   'movieId': 27,
#   'title': 'Now and Then (1995)',
#   'movielens_genres': 'Children|Drama',
#   'avg_rating': 3.3333333333333335,
#   'number_of_viewers': 9.0,
#   'imdbId': 114011,
#   'tmdbId': 9263.0},
#  {'Unnamed: 0': 27,
#   'movieId': 28,
#   'title': 'Persuasion (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 4.2272727272727275,
#   'number_of_viewers': 11.0,
#   'imdbId': 114117,
#   'tmdbId': 17015.0},
#  {'Unnamed: 0': 28,
#   'movieId': 29,
#   'title': 'City of Lost Children, The (Cité des enfants perdus, La) (1995)',
#   'movielens_genres': 'Adventure|Drama|Fantasy|Mystery|Sci-Fi',
#   'avg_rating': 4.0131578947368425,
#   'number_of_viewers': 38.0,
#   'imdbId': 112682,
#   'tmdbId': 902.0},
#  {'Unnamed: 0': 29,
#   'movieId': 30,
#   'title': 'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)',
#   'movielens_genres': 'Crime|Drama',
#   'avg_rating': 3.0,
#   'number_of_viewers': 3.0,
#   'imdbId': 115012,
#   'tmdbId': 37557.0},
#  {'Unnamed: 0': 30,
#   'movieId': 31,
#   'title': 'Dangerous Minds (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.1842105263157894,
#   'number_of_viewers': 38.0,
#   'imdbId': 112792,
#   'tmdbId': 9909.0},
#  {'Unnamed: 0': 31,
#   'movieId': 32,
#   'title': 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)',
#   'movielens_genres': 'Mystery|Sci-Fi|Thriller',
#   'avg_rating': 3.983050847457627,
#   'number_of_viewers': 177.0,
#   'imdbId': 114746,
#   'tmdbId': 63.0},
#  {'Unnamed: 0': 32,
#   'movieId': 34,
#   'title': 'Babe (1995)',
#   'movielens_genres': 'Children|Drama',
#   'avg_rating': 3.65234375,
#   'number_of_viewers': 128.0,
#   'imdbId': 112431,
#   'tmdbId': 9598.0},
#  {'Unnamed: 0': 33,
#   'movieId': 36,
#   'title': 'Dead Man Walking (1995)',
#   'movielens_genres': 'Crime|Drama',
#   'avg_rating': 3.835820895522388,
#   'number_of_viewers': 67.0,
#   'imdbId': 112818,
#   'tmdbId': 687.0},
#  {'Unnamed: 0': 34,
#   'movieId': 38,
#   'title': 'It Takes Two (1995)',
#   'movielens_genres': 'Children|Comedy',
#   'avg_rating': 2.125,
#   'number_of_viewers': 4.0,
#   'imdbId': 113442,
#   'tmdbId': 33689.0},
#  {'Unnamed: 0': 35,
#   'movieId': 39,
#   'title': 'Clueless (1995)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.293269230769231,
#   'number_of_viewers': 104.0,
#   'imdbId': 112697,
#   'tmdbId': 9603.0},
#  {'Unnamed: 0': 36,
#   'movieId': 40,
#   'title': 'Cry, the Beloved Country (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 4.25,
#   'number_of_viewers': 2.0,
#   'imdbId': 112749,
#   'tmdbId': 34615.0},
#  {'Unnamed: 0': 37,
#   'movieId': 41,
#   'title': 'Richard III (1995)',
#   'movielens_genres': 'Drama|War',
#   'avg_rating': 3.7,
#   'number_of_viewers': 15.0,
#   'imdbId': 114279,
#   'tmdbId': 31174.0},
#  {'Unnamed: 0': 38,
#   'movieId': 42,
#   'title': 'Dead Presidents (1995)',
#   'movielens_genres': 'Action|Crime|Drama',
#   'avg_rating': 3.0,
#   'number_of_viewers': 7.0,
#   'imdbId': 112819,
#   'tmdbId': 11443.0},
#  {'Unnamed: 0': 39,
#   'movieId': 43,
#   'title': 'Restoration (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.1875,
#   'number_of_viewers': 8.0,
#   'imdbId': 114272,
#   'tmdbId': 35196.0},
#  {'Unnamed: 0': 40,
#   'movieId': 44,
#   'title': 'Mortal Kombat (1995)',
#   'movielens_genres': 'Action|Adventure|Fantasy',
#   'avg_rating': 2.5434782608695654,
#   'number_of_viewers': 46.0,
#   'imdbId': 113855,
#   'tmdbId': 9312.0},
#  {'Unnamed: 0': 41,
#   'movieId': 45,
#   'title': 'To Die For (1995)',
#   'movielens_genres': 'Comedy|Drama|Thriller',
#   'avg_rating': 3.3125,
#   'number_of_viewers': 32.0,
#   'imdbId': 114681,
#   'tmdbId': 577.0},
#  {'Unnamed: 0': 42,
#   'movieId': 46,
#   'title': 'How to Make an American Quilt (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.066666666666667,
#   'number_of_viewers': 15.0,
#   'imdbId': 113347,
#   'tmdbId': 11861.0},
#  {'Unnamed: 0': 43,
#   'movieId': 47,
#   'title': 'Seven (a.k.a. Se7en) (1995)',
#   'movielens_genres': 'Mystery|Thriller',
#   'avg_rating': 3.9753694581280783,
#   'number_of_viewers': 203.0,
#   'imdbId': 114369,
#   'tmdbId': 807.0},
#  {'Unnamed: 0': 44,
#   'movieId': 48,
#   'title': 'Pocahontas (1995)',
#   'movielens_genres': 'Animation|Children|Drama|Musical|Romance',
#   'avg_rating': 3.1470588235294117,
#   'number_of_viewers': 68.0,
#   'imdbId': 114148,
#   'tmdbId': 10530.0},
#  {'Unnamed: 0': 45,
#   'movieId': 49,
#   'title': 'When Night Is Falling (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 114916,
#   'tmdbId': 8391.0},
#  {'Unnamed: 0': 46,
#   'movieId': 50,
#   'title': 'Usual Suspects, The (1995)',
#   'movielens_genres': 'Crime|Mystery|Thriller',
#   'avg_rating': 4.237745098039215,
#   'number_of_viewers': 204.0,
#   'imdbId': 114814,
#   'tmdbId': 629.0},
#  {'Unnamed: 0': 47,
#   'movieId': 52,
#   'title': 'Mighty Aphrodite (1995)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 3.4642857142857144,
#   'number_of_viewers': 28.0,
#   'imdbId': 113819,
#   'tmdbId': 11448.0},
#  {'Unnamed: 0': 48,
#   'movieId': 53,
#   'title': 'Lamerica (1994)',
#   'movielens_genres': 'Adventure|Drama',
#   'avg_rating': 5.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 110299,
#   'tmdbId': 49133.0},
#  {'Unnamed: 0': 49,
#   'movieId': 54,
#   'title': 'Big Green, The (1995)',
#   'movielens_genres': 'Children|Comedy',
#   'avg_rating': 2.3333333333333335,
#   'number_of_viewers': 3.0,
#   'imdbId': 112499,
#   'tmdbId': 26441.0},
#  {'Unnamed: 0': 50,
#   'movieId': 55,
#   'title': 'Georgia (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 4.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 113158,
#   'tmdbId': 97406.0},
#  {'Unnamed: 0': 51,
#   'movieId': 57,
#   'title': 'Home for the Holidays (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.0625,
#   'number_of_viewers': 8.0,
#   'imdbId': 113321,
#   'tmdbId': 9089.0},
#  {'Unnamed: 0': 52,
#   'movieId': 58,
#   'title': 'Postman, The (Postino, Il) (1994)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 4.027027027027027,
#   'number_of_viewers': 37.0,
#   'imdbId': 110877,
#   'tmdbId': 11010.0},
#  {'Unnamed: 0': 53,
#   'movieId': 60,
#   'title': 'Indian in the Cupboard, The (1995)',
#   'movielens_genres': 'Adventure|Children|Fantasy',
#   'avg_rating': 3.235294117647059,
#   'number_of_viewers': 34.0,
#   'imdbId': 113419,
#   'tmdbId': 11359.0},
#  {'Unnamed: 0': 54,
#   'movieId': 61,
#   'title': 'Eye for an Eye (1996)',
#   'movielens_genres': 'Drama|Thriller',
#   'avg_rating': 3.75,
#   'number_of_viewers': 6.0,
#   'imdbId': 116260,
#   'tmdbId': 17182.0},
#  {'Unnamed: 0': 55,
#   'movieId': 62,
#   'title': "Mr. Holland's Opus (1995)",
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.70625,
#   'number_of_viewers': 80.0,
#   'imdbId': 113862,
#   'tmdbId': 2054.0},
#  {'Unnamed: 0': 56,
#   'movieId': 63,
#   'title': "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)",
#   'movielens_genres': 'Comedy|Crime',
#   'avg_rating': 2.7142857142857144,
#   'number_of_viewers': 7.0,
#   'imdbId': 116126,
#   'tmdbId': 10607.0},
#  {'Unnamed: 0': 57,
#   'movieId': 64,
#   'title': 'Two if by Sea (1996)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 2.2,
#   'number_of_viewers': 5.0,
#   'imdbId': 118002,
#   'tmdbId': 19760.0},
#  {'Unnamed: 0': 58,
#   'movieId': 65,
#   'title': 'Bio-Dome (1996)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.532258064516129,
#   'number_of_viewers': 31.0,
#   'imdbId': 115683,
#   'tmdbId': 9536.0},
#  {'Unnamed: 0': 59,
#   'movieId': 66,
#   'title': 'Lawnmower Man 2: Beyond Cyberspace (1996)',
#   'movielens_genres': 'Action|Sci-Fi|Thriller',
#   'avg_rating': 2.5,
#   'number_of_viewers': 9.0,
#   'imdbId': 116839,
#   'tmdbId': 11525.0},
#  {'Unnamed: 0': 60,
#   'movieId': 68,
#   'title': 'French Twist (Gazon maudit) (1995)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.4,
#   'number_of_viewers': 5.0,
#   'imdbId': 113149,
#   'tmdbId': 4482.0},
#  {'Unnamed: 0': 61,
#   'movieId': 69,
#   'title': 'Friday (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.775,
#   'number_of_viewers': 20.0,
#   'imdbId': 113118,
#   'tmdbId': 10634.0},
#  {'Unnamed: 0': 62,
#   'movieId': 70,
#   'title': 'From Dusk Till Dawn (1996)',
#   'movielens_genres': 'Action|Comedy|Horror|Thriller',
#   'avg_rating': 3.5090909090909093,
#   'number_of_viewers': 55.0,
#   'imdbId': 116367,
#   'tmdbId': 755.0},
#  {'Unnamed: 0': 63,
#   'movieId': 71,
#   'title': 'Fair Game (1995)',
#   'movielens_genres': 'Action',
#   'avg_rating': 1.7,
#   'number_of_viewers': 5.0,
#   'imdbId': 113010,
#   'tmdbId': 11859.0},
#  {'Unnamed: 0': 64,
#   'movieId': 72,
#   'title': 'Kicking and Screaming (1995)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.2142857142857144,
#   'number_of_viewers': 7.0,
#   'imdbId': 113537,
#   'tmdbId': 28387.0},
#  {'Unnamed: 0': 65,
#   'movieId': 73,
#   'title': 'Misérables, Les (1995)',
#   'movielens_genres': 'Drama|War',
#   'avg_rating': 3.4615384615384617,
#   'number_of_viewers': 13.0,
#   'imdbId': 113828,
#   'tmdbId': 48750.0},
#  {'Unnamed: 0': 66,
#   'movieId': 74,
#   'title': 'Bed of Roses (1996)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 4.0,
#   'number_of_viewers': 8.0,
#   'imdbId': 115644,
#   'tmdbId': 20927.0},
#  {'Unnamed: 0': 67,
#   'movieId': 75,
#   'title': 'Big Bully (1996)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 2.2,
#   'number_of_viewers': 5.0,
#   'imdbId': 115676,
#   'tmdbId': 36929.0},
#  {'Unnamed: 0': 68,
#   'movieId': 76,
#   'title': 'Screamers (1995)',
#   'movielens_genres': 'Action|Sci-Fi|Thriller',
#   'avg_rating': 3.4,
#   'number_of_viewers': 15.0,
#   'imdbId': 114367,
#   'tmdbId': 9102.0},
#  {'Unnamed: 0': 69,
#   'movieId': 77,
#   'title': 'Nico Icon (1995)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 4.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 113973,
#   'tmdbId': 124626.0},
#  {'Unnamed: 0': 70,
#   'movieId': 78,
#   'title': 'Crossing Guard, The (1995)',
#   'movielens_genres': 'Action|Crime|Drama|Thriller',
#   'avg_rating': 3.3333333333333335,
#   'number_of_viewers': 3.0,
#   'imdbId': 112744,
#   'tmdbId': 27526.0},
#  {'Unnamed: 0': 71,
#   'movieId': 79,
#   'title': 'Juror, The (1996)',
#   'movielens_genres': 'Drama|Thriller',
#   'avg_rating': 2.764705882352941,
#   'number_of_viewers': 17.0,
#   'imdbId': 116731,
#   'tmdbId': 9623.0},
#  {'Unnamed: 0': 72,
#   'movieId': 80,
#   'title': 'White Balloon, The (Badkonake sefid) (1995)',
#   'movielens_genres': 'Children|Drama',
#   'avg_rating': 4.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 112445,
#   'tmdbId': 46785.0},
#  {'Unnamed: 0': 73,
#   'movieId': 81,
#   'title': "Things to Do in Denver When You're Dead (1995)",
#   'movielens_genres': 'Crime|Drama|Romance',
#   'avg_rating': 3.107142857142857,
#   'number_of_viewers': 14.0,
#   'imdbId': 114660,
#   'tmdbId': 400.0},
#  {'Unnamed: 0': 74,
#   'movieId': 82,
#   'title': "Antonia's Line (Antonia) (1995)",
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.875,
#   'number_of_viewers': 8.0,
#   'imdbId': 112379,
#   'tmdbId': 880.0},
#  {'Unnamed: 0': 75,
#   'movieId': 83,
#   'title': 'Once Upon a Time... When We Were Colored (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 114039,
#   'tmdbId': 146599.0},
#  {'Unnamed: 0': 76,
#   'movieId': 85,
#   'title': 'Angels and Insects (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.857142857142857,
#   'number_of_viewers': 7.0,
#   'imdbId': 112365,
#   'tmdbId': 8447.0},
#  {'Unnamed: 0': 77,
#   'movieId': 86,
#   'title': 'White Squall (1996)',
#   'movielens_genres': 'Action|Adventure|Drama',
#   'avg_rating': 3.966666666666667,
#   'number_of_viewers': 15.0,
#   'imdbId': 118158,
#   'tmdbId': 10534.0},
#  {'Unnamed: 0': 78,
#   'movieId': 87,
#   'title': 'Dunston Checks In (1996)',
#   'movielens_genres': 'Children|Comedy',
#   'avg_rating': 2.5,
#   'number_of_viewers': 7.0,
#   'imdbId': 116151,
#   'tmdbId': 17414.0},
#  {'Unnamed: 0': 79,
#   'movieId': 88,
#   'title': 'Black Sheep (1996)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.15625,
#   'number_of_viewers': 16.0,
#   'imdbId': 115697,
#   'tmdbId': 13997.0},
#  {'Unnamed: 0': 80,
#   'movieId': 89,
#   'title': 'Nick of Time (1995)',
#   'movielens_genres': 'Action|Thriller',
#   'avg_rating': 3.25,
#   'number_of_viewers': 10.0,
#   'imdbId': 113972,
#   'tmdbId': 2086.0},
#  {'Unnamed: 0': 81,
#   'movieId': 92,
#   'title': 'Mary Reilly (1996)',
#   'movielens_genres': 'Drama|Horror|Thriller',
#   'avg_rating': 2.625,
#   'number_of_viewers': 8.0,
#   'imdbId': 117002,
#   'tmdbId': 9095.0},
#  {'Unnamed: 0': 82,
#   'movieId': 93,
#   'title': 'Vampire in Brooklyn (1995)',
#   'movielens_genres': 'Comedy|Horror|Romance',
#   'avg_rating': 2.8333333333333335,
#   'number_of_viewers': 9.0,
#   'imdbId': 114825,
#   'tmdbId': 12158.0},
#  {'Unnamed: 0': 83,
#   'movieId': 94,
#   'title': 'Beautiful Girls (1996)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 3.95,
#   'number_of_viewers': 10.0,
#   'imdbId': 115639,
#   'tmdbId': 9283.0},
#  {'Unnamed: 0': 84,
#   'movieId': 95,
#   'title': 'Broken Arrow (1996)',
#   'movielens_genres': 'Action|Adventure|Thriller',
#   'avg_rating': 3.0238095238095237,
#   'number_of_viewers': 84.0,
#   'imdbId': 115759,
#   'tmdbId': 9208.0},
#  {'Unnamed: 0': 85,
#   'movieId': 96,
#   'title': 'In the Bleak Midwinter (1995)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.5,
#   'number_of_viewers': 1.0,
#   'imdbId': 113403,
#   'tmdbId': 40154.0},
#  {'Unnamed: 0': 86,
#   'movieId': 97,
#   'title': 'Hate (Haine, La) (1995)',
#   'movielens_genres': 'Crime|Drama',
#   'avg_rating': 3.9,
#   'number_of_viewers': 10.0,
#   'imdbId': 113247,
#   'tmdbId': 406.0},
#  {'Unnamed: 0': 87,
#   'movieId': 99,
#   'title': 'Heidi Fleiss: Hollywood Madam (1995)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 5.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 113283,
#   'tmdbId': 63076.0},
#  {'Unnamed: 0': 88,
#   'movieId': 100,
#   'title': 'City Hall (1996)',
#   'movielens_genres': 'Drama|Thriller',
#   'avg_rating': 2.7857142857142856,
#   'number_of_viewers': 14.0,
#   'imdbId': 115907,
#   'tmdbId': 11062.0},
#  {'Unnamed: 0': 89,
#   'movieId': 101,
#   'title': 'Bottle Rocket (1996)',
#   'movielens_genres': 'Adventure|Comedy|Crime|Romance',
#   'avg_rating': 3.782608695652174,
#   'number_of_viewers': 23.0,
#   'imdbId': 115734,
#   'tmdbId': 13685.0},
#  {'Unnamed: 0': 90,
#   'movieId': 102,
#   'title': 'Mr. Wrong (1996)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.4,
#   'number_of_viewers': 5.0,
#   'imdbId': 117102,
#   'tmdbId': 47475.0},
#  {'Unnamed: 0': 91,
#   'movieId': 103,
#   'title': 'Unforgettable (1996)',
#   'movielens_genres': 'Mystery|Sci-Fi|Thriller',
#   'avg_rating': 3.0,
#   'number_of_viewers': 3.0,
#   'imdbId': 118040,
#   'tmdbId': 2045.0},
#  {'Unnamed: 0': 92,
#   'movieId': 104,
#   'title': 'Happy Gilmore (1996)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.439393939393939,
#   'number_of_viewers': 99.0,
#   'imdbId': 116483,
#   'tmdbId': 9614.0},
#  {'Unnamed: 0': 93,
#   'movieId': 105,
#   'title': 'Bridges of Madison County, The (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.282608695652174,
#   'number_of_viewers': 23.0,
#   'imdbId': 112579,
#   'tmdbId': 688.0},
#  {'Unnamed: 0': 94,
#   'movieId': 106,
#   'title': 'Nobody Loves Me (Keiner liebt mich) (1994)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 4.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 110251,
#   'tmdbId': 11907.0},
#  {'Unnamed: 0': 95,
#   'movieId': 107,
#   'title': 'Muppet Treasure Island (1996)',
#   'movielens_genres': 'Adventure|Children|Comedy|Musical',
#   'avg_rating': 3.326923076923077,
#   'number_of_viewers': 26.0,
#   'imdbId': 117110,
#   'tmdbId': 10874.0},
#  {'Unnamed: 0': 96,
#   'movieId': 108,
#   'title': 'Catwalk (1996)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 4.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 112646,
#   'tmdbId': 89333.0},
#  {'Unnamed: 0': 97,
#   'movieId': 110,
#   'title': 'Braveheart (1995)',
#   'movielens_genres': 'Action|Drama|War',
#   'avg_rating': 4.031645569620253,
#   'number_of_viewers': 237.0,
#   'imdbId': 112573,
#   'tmdbId': 197.0},
#  {'Unnamed: 0': 98,
#   'movieId': 111,
#   'title': 'Taxi Driver (1976)',
#   'movielens_genres': 'Crime|Drama|Thriller',
#   'avg_rating': 4.105769230769231,
#   'number_of_viewers': 104.0,
#   'imdbId': 75314,
#   'tmdbId': 103.0},
#  {'Unnamed: 0': 99,
#   'movieId': 112,
#   'title': 'Rumble in the Bronx (Hont faan kui) (1995)',
#   'movielens_genres': 'Action|Adventure|Comedy|Crime',
#   'avg_rating': 3.5434782608695654,
#   'number_of_viewers': 46.0,
#   'imdbId': 113326,
#   'tmdbId': 33542.0},
#  {'Unnamed: 0': 100,
#   'movieId': 113,
#   'title': 'Before and After (1996)',
#   'movielens_genres': 'Drama|Mystery',
#   'avg_rating': 3.3333333333333335,
#   'number_of_viewers': 3.0,
#   'imdbId': 115645,
#   'tmdbId': 43566.0},
#  {'Unnamed: 0': 101,
#   'movieId': 116,
#   'title': 'Anne Frank Remembered (1995)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 3.9,
#   'number_of_viewers': 5.0,
#   'imdbId': 112373,
#   'tmdbId': 51352.0},
#  {'Unnamed: 0': 102,
#   'movieId': 117,
#   'title': "Young Poisoner's Handbook, The (1995)",
#   'movielens_genres': 'Crime|Drama',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 115033,
#   'tmdbId': 16934.0},
#  {'Unnamed: 0': 103,
#   'movieId': 118,
#   'title': 'If Lucy Fell (1996)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 2.5,
#   'number_of_viewers': 2.0,
#   'imdbId': 116606,
#   'tmdbId': 10324.0},
#  {'Unnamed: 0': 104,
#   'movieId': 119,
#   'title': 'Steal Big, Steal Little (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 114536,
#   'tmdbId': 78406.0},
#  {'Unnamed: 0': 105,
#   'movieId': 121,
#   'title': 'Boys of St. Vincent, The (1992)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 4.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 106473,
#   'tmdbId': 32119.0},
#  {'Unnamed: 0': 106,
#   'movieId': 122,
#   'title': 'Boomerang (1992)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 2.65625,
#   'number_of_viewers': 16.0,
#   'imdbId': 103859,
#   'tmdbId': 11066.0},
#  {'Unnamed: 0': 107,
#   'movieId': 123,
#   'title': 'Chungking Express (Chung Hing sam lam) (1994)',
#   'movielens_genres': 'Drama|Mystery|Romance',
#   'avg_rating': 4.375,
#   'number_of_viewers': 4.0,
#   'imdbId': 109424,
#   'tmdbId': 11104.0},
#  {'Unnamed: 0': 108,
#   'movieId': 125,
#   'title': 'Flirting With Disaster (1996)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.5833333333333335,
#   'number_of_viewers': 12.0,
#   'imdbId': 116324,
#   'tmdbId': 2074.0},
#  {'Unnamed: 0': 109,
#   'movieId': 126,
#   'title': 'NeverEnding Story III, The (1994)',
#   'movielens_genres': 'Adventure|Children|Fantasy',
#   'avg_rating': 2.0,
#   'number_of_viewers': 7.0,
#   'imdbId': 110647,
#   'tmdbId': 27793.0},
#  {'Unnamed: 0': 110,
#   'movieId': 128,
#   'title': "Jupiter's Wife (1994)",
#   'movielens_genres': 'Documentary',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 110217,
#   'tmdbId': 290157.0},
#  {'Unnamed: 0': 111,
#   'movieId': 129,
#   'title': 'Pie in the Sky (1996)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 2.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 114131,
#   'tmdbId': 110972.0},
#  {'Unnamed: 0': 112,
#   'movieId': 132,
#   'title': 'Jade (1995)',
#   'movielens_genres': 'Thriller',
#   'avg_rating': 2.8333333333333335,
#   'number_of_viewers': 6.0,
#   'imdbId': 113451,
#   'tmdbId': 11863.0},
#  {'Unnamed: 0': 113,
#   'movieId': 135,
#   'title': 'Down Periscope (1996)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.9516129032258065,
#   'number_of_viewers': 31.0,
#   'imdbId': 116130,
#   'tmdbId': 9101.0},
#  {'Unnamed: 0': 114,
#   'movieId': 137,
#   'title': 'Man of the Year (1995)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 113756,
#   'tmdbId': 5757.0},
#  {'Unnamed: 0': 115,
#   'movieId': 140,
#   'title': 'Up Close and Personal (1996)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.5,
#   'number_of_viewers': 16.0,
#   'imdbId': 118055,
#   'tmdbId': 9302.0},
#  {'Unnamed: 0': 116,
#   'movieId': 141,
#   'title': 'Birdcage, The (1996)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.494186046511628,
#   'number_of_viewers': 86.0,
#   'imdbId': 115685,
#   'tmdbId': 11000.0},
#  {'Unnamed: 0': 117,
#   'movieId': 144,
#   'title': 'Brothers McMullen, The (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.3333333333333335,
#   'number_of_viewers': 12.0,
#   'imdbId': 112585,
#   'tmdbId': 16388.0},
#  {'Unnamed: 0': 118,
#   'movieId': 145,
#   'title': 'Bad Boys (1995)',
#   'movielens_genres': 'Action|Comedy|Crime|Drama|Thriller',
#   'avg_rating': 3.2450980392156863,
#   'number_of_viewers': 51.0,
#   'imdbId': 112442,
#   'tmdbId': 9737.0},
#  {'Unnamed: 0': 119,
#   'movieId': 146,
#   'title': 'Amazing Panda Adventure, The (1995)',
#   'movielens_genres': 'Adventure|Children',
#   'avg_rating': 3.3333333333333335,
#   'number_of_viewers': 3.0,
#   'imdbId': 112342,
#   'tmdbId': 30765.0},
#  {'Unnamed: 0': 120,
#   'movieId': 147,
#   'title': 'Basketball Diaries, The (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.466666666666667,
#   'number_of_viewers': 15.0,
#   'imdbId': 112461,
#   'tmdbId': 10474.0},
#  {'Unnamed: 0': 121,
#   'movieId': 148,
#   'title': 'Awfully Big Adventure, An (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 5.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 112427,
#   'tmdbId': 22279.0},
#  {'Unnamed: 0': 122,
#   'movieId': 149,
#   'title': 'Amateur (1994)',
#   'movielens_genres': 'Crime|Drama|Thriller',
#   'avg_rating': 2.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 109093,
#   'tmdbId': 30157.0},
#  {'Unnamed: 0': 123,
#   'movieId': 150,
#   'title': 'Apollo 13 (1995)',
#   'movielens_genres': 'Adventure|Drama|IMAX',
#   'avg_rating': 3.845771144278607,
#   'number_of_viewers': 201.0,
#   'imdbId': 112384,
#   'tmdbId': 568.0},
#  {'Unnamed: 0': 124,
#   'movieId': 151,
#   'title': 'Rob Roy (1995)',
#   'movielens_genres': 'Action|Drama|Romance|War',
#   'avg_rating': 3.5454545454545454,
#   'number_of_viewers': 44.0,
#   'imdbId': 114287,
#   'tmdbId': 11780.0},
#  {'Unnamed: 0': 125,
#   'movieId': 152,
#   'title': 'Addiction, The (1995)',
#   'movielens_genres': 'Drama|Horror',
#   'avg_rating': 1.5,
#   'number_of_viewers': 2.0,
#   'imdbId': 112288,
#   'tmdbId': 34996.0},
#  {'Unnamed: 0': 126,
#   'movieId': 153,
#   'title': 'Batman Forever (1995)',
#   'movielens_genres': 'Action|Adventure|Comedy|Crime',
#   'avg_rating': 2.916058394160584,
#   'number_of_viewers': 137.0,
#   'imdbId': 112462,
#   'tmdbId': 414.0},
#  {'Unnamed: 0': 127,
#   'movieId': 154,
#   'title': 'Beauty of the Day (Belle de jour) (1967)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.875,
#   'number_of_viewers': 12.0,
#   'imdbId': 61395,
#   'tmdbId': 649.0},
#  {'Unnamed: 0': 128,
#   'movieId': 155,
#   'title': 'Beyond Rangoon (1995)',
#   'movielens_genres': 'Adventure|Drama|War',
#   'avg_rating': 2.4166666666666665,
#   'number_of_viewers': 6.0,
#   'imdbId': 112495,
#   'tmdbId': 1873.0},
#  {'Unnamed: 0': 129,
#   'movieId': 156,
#   'title': 'Blue in the Face (1995)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.3333333333333335,
#   'number_of_viewers': 3.0,
#   'imdbId': 112541,
#   'tmdbId': 5894.0},
#  {'Unnamed: 0': 130,
#   'movieId': 157,
#   'title': 'Canadian Bacon (1995)',
#   'movielens_genres': 'Comedy|War',
#   'avg_rating': 2.863636363636364,
#   'number_of_viewers': 11.0,
#   'imdbId': 109370,
#   'tmdbId': 1775.0},
#  {'Unnamed: 0': 131,
#   'movieId': 158,
#   'title': 'Casper (1995)',
#   'movielens_genres': 'Adventure|Children',
#   'avg_rating': 2.806451612903226,
#   'number_of_viewers': 62.0,
#   'imdbId': 112642,
#   'tmdbId': 8839.0},
#  {'Unnamed: 0': 132,
#   'movieId': 159,
#   'title': 'Clockers (1995)',
#   'movielens_genres': 'Crime|Drama|Mystery',
#   'avg_rating': 2.892857142857143,
#   'number_of_viewers': 14.0,
#   'imdbId': 112688,
#   'tmdbId': 20649.0},
#  {'Unnamed: 0': 133,
#   'movieId': 160,
#   'title': 'Congo (1995)',
#   'movielens_genres': 'Action|Adventure|Mystery|Sci-Fi',
#   'avg_rating': 2.8771929824561404,
#   'number_of_viewers': 57.0,
#   'imdbId': 112715,
#   'tmdbId': 10329.0},
#  {'Unnamed: 0': 134,
#   'movieId': 161,
#   'title': 'Crimson Tide (1995)',
#   'movielens_genres': 'Drama|Thriller|War',
#   'avg_rating': 3.6359223300970873,
#   'number_of_viewers': 103.0,
#   'imdbId': 112740,
#   'tmdbId': 8963.0},
#  {'Unnamed: 0': 135,
#   'movieId': 162,
#   'title': 'Crumb (1994)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 4.205882352941177,
#   'number_of_viewers': 17.0,
#   'imdbId': 109508,
#   'tmdbId': 26564.0},
#  {'Unnamed: 0': 136,
#   'movieId': 163,
#   'title': 'Desperado (1995)',
#   'movielens_genres': 'Action|Romance|Western',
#   'avg_rating': 3.560606060606061,
#   'number_of_viewers': 66.0,
#   'imdbId': 112851,
#   'tmdbId': 8068.0},
#  {'Unnamed: 0': 137,
#   'movieId': 164,
#   'title': 'Devil in a Blue Dress (1995)',
#   'movielens_genres': 'Crime|Film-Noir|Mystery|Thriller',
#   'avg_rating': 3.3214285714285716,
#   'number_of_viewers': 14.0,
#   'imdbId': 112857,
#   'tmdbId': 8512.0},
#  {'Unnamed: 0': 138,
#   'movieId': 165,
#   'title': 'Die Hard: With a Vengeance (1995)',
#   'movielens_genres': 'Action|Crime|Thriller',
#   'avg_rating': 3.5555555555555554,
#   'number_of_viewers': 144.0,
#   'imdbId': 112864,
#   'tmdbId': 1572.0},
#  {'Unnamed: 0': 139,
#   'movieId': 166,
#   'title': 'Doom Generation, The (1995)',
#   'movielens_genres': 'Comedy|Crime|Drama',
#   'avg_rating': 2.8333333333333335,
#   'number_of_viewers': 3.0,
#   'imdbId': 112887,
#   'tmdbId': 13552.0},
#  {'Unnamed: 0': 140,
#   'movieId': 168,
#   'title': 'First Knight (1995)',
#   'movielens_genres': 'Action|Drama|Romance',
#   'avg_rating': 3.0833333333333335,
#   'number_of_viewers': 54.0,
#   'imdbId': 113071,
#   'tmdbId': 6520.0},
#  {'Unnamed: 0': 141,
#   'movieId': 169,
#   'title': 'Free Willy 2: The Adventure Home (1995)',
#   'movielens_genres': 'Adventure|Children|Drama',
#   'avg_rating': 2.4,
#   'number_of_viewers': 10.0,
#   'imdbId': 113114,
#   'tmdbId': 9073.0},
#  {'Unnamed: 0': 142,
#   'movieId': 170,
#   'title': 'Hackers (1995)',
#   'movielens_genres': 'Action|Adventure|Crime|Thriller',
#   'avg_rating': 3.2285714285714286,
#   'number_of_viewers': 35.0,
#   'imdbId': 113243,
#   'tmdbId': 10428.0},
#  {'Unnamed: 0': 143,
#   'movieId': 171,
#   'title': 'Jeffrey (1995)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.8333333333333335,
#   'number_of_viewers': 6.0,
#   'imdbId': 113464,
#   'tmdbId': 17447.0},
#  {'Unnamed: 0': 144,
#   'movieId': 172,
#   'title': 'Johnny Mnemonic (1995)',
#   'movielens_genres': 'Action|Sci-Fi|Thriller',
#   'avg_rating': 2.679245283018868,
#   'number_of_viewers': 53.0,
#   'imdbId': 113481,
#   'tmdbId': 9886.0},
#  {'Unnamed: 0': 145,
#   'movieId': 173,
#   'title': 'Judge Dredd (1995)',
#   'movielens_genres': 'Action|Crime|Sci-Fi',
#   'avg_rating': 2.6693548387096775,
#   'number_of_viewers': 62.0,
#   'imdbId': 113492,
#   'tmdbId': 9482.0},
#  {'Unnamed: 0': 146,
#   'movieId': 174,
#   'title': 'Jury Duty (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.7,
#   'number_of_viewers': 10.0,
#   'imdbId': 113500,
#   'tmdbId': 19326.0},
#  {'Unnamed: 0': 147,
#   'movieId': 175,
#   'title': 'Kids (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.975,
#   'number_of_viewers': 20.0,
#   'imdbId': 113540,
#   'tmdbId': 9344.0},
#  {'Unnamed: 0': 148,
#   'movieId': 176,
#   'title': 'Living in Oblivion (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 4.3076923076923075,
#   'number_of_viewers': 13.0,
#   'imdbId': 113677,
#   'tmdbId': 9071.0},
#  {'Unnamed: 0': 149,
#   'movieId': 177,
#   'title': 'Lord of Illusions (1995)',
#   'movielens_genres': 'Horror',
#   'avg_rating': 2.75,
#   'number_of_viewers': 8.0,
#   'imdbId': 113690,
#   'tmdbId': 8973.0},
#  {'Unnamed: 0': 150,
#   'movieId': 178,
#   'title': 'Love & Human Remains (1993)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 1.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 107447,
#   'tmdbId': 15730.0},
#  {'Unnamed: 0': 151,
#   'movieId': 179,
#   'title': 'Mad Love (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 1.5,
#   'number_of_viewers': 2.0,
#   'imdbId': 113729,
#   'tmdbId': 47608.0},
#  {'Unnamed: 0': 152,
#   'movieId': 180,
#   'title': 'Mallrats (1995)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.4027777777777777,
#   'number_of_viewers': 36.0,
#   'imdbId': 113749,
#   'tmdbId': 2293.0},
#  {'Unnamed: 0': 153,
#   'movieId': 181,
#   'title': 'Mighty Morphin Power Rangers: The Movie (1995)',
#   'movielens_genres': 'Action|Children',
#   'avg_rating': 2.264705882352941,
#   'number_of_viewers': 17.0,
#   'imdbId': 113820,
#   'tmdbId': 9070.0},
#  {'Unnamed: 0': 154,
#   'movieId': 183,
#   'title': 'Mute Witness (1994)',
#   'movielens_genres': 'Comedy|Horror|Thriller',
#   'avg_rating': 3.5,
#   'number_of_viewers': 2.0,
#   'imdbId': 110604,
#   'tmdbId': 48787.0},
#  {'Unnamed: 0': 155,
#   'movieId': 184,
#   'title': 'Nadja (1994)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.5,
#   'number_of_viewers': 2.0,
#   'imdbId': 110620,
#   'tmdbId': 34574.0},
#  {'Unnamed: 0': 156,
#   'movieId': 185,
#   'title': 'Net, The (1995)',
#   'movielens_genres': 'Action|Crime|Thriller',
#   'avg_rating': 3.0401785714285716,
#   'number_of_viewers': 112.0,
#   'imdbId': 113957,
#   'tmdbId': 1642.0},
#  {'Unnamed: 0': 157,
#   'movieId': 186,
#   'title': 'Nine Months (1995)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 2.8229166666666665,
#   'number_of_viewers': 48.0,
#   'imdbId': 113986,
#   'tmdbId': 11472.0},
#  {'Unnamed: 0': 158,
#   'movieId': 187,
#   'title': 'Party Girl (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 4.125,
#   'number_of_viewers': 4.0,
#   'imdbId': 114095,
#   'tmdbId': 36196.0},
#  {'Unnamed: 0': 159,
#   'movieId': 188,
#   'title': 'Prophecy, The (1995)',
#   'movielens_genres': 'Fantasy|Horror|Mystery',
#   'avg_rating': 3.4583333333333335,
#   'number_of_viewers': 12.0,
#   'imdbId': 114194,
#   'tmdbId': 11980.0},
#  {'Unnamed: 0': 160,
#   'movieId': 189,
#   'title': 'Reckless (1995)',
#   'movielens_genres': 'Comedy|Fantasy',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 114241,
#   'tmdbId': 58372.0},
#  {'Unnamed: 0': 161,
#   'movieId': 190,
#   'title': 'Safe (1995)',
#   'movielens_genres': 'Thriller',
#   'avg_rating': 2.8,
#   'number_of_viewers': 5.0,
#   'imdbId': 114323,
#   'tmdbId': 32646.0},
#  {'Unnamed: 0': 162,
#   'movieId': 191,
#   'title': 'Scarlet Letter, The (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 2.4166666666666665,
#   'number_of_viewers': 6.0,
#   'imdbId': 114345,
#   'tmdbId': 10533.0},
#  {'Unnamed: 0': 163,
#   'movieId': 193,
#   'title': 'Showgirls (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 2.4714285714285715,
#   'number_of_viewers': 35.0,
#   'imdbId': 114436,
#   'tmdbId': 10802.0},
#  {'Unnamed: 0': 164,
#   'movieId': 194,
#   'title': 'Smoke (1995)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.6666666666666665,
#   'number_of_viewers': 18.0,
#   'imdbId': 114478,
#   'tmdbId': 10149.0},
#  {'Unnamed: 0': 165,
#   'movieId': 195,
#   'title': 'Something to Talk About (1995)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 3.1,
#   'number_of_viewers': 10.0,
#   'imdbId': 114496,
#   'tmdbId': 18402.0},
#  {'Unnamed: 0': 166,
#   'movieId': 196,
#   'title': 'Species (1995)',
#   'movielens_genres': 'Horror|Sci-Fi',
#   'avg_rating': 2.6666666666666665,
#   'number_of_viewers': 45.0,
#   'imdbId': 114508,
#   'tmdbId': 9348.0},
#  {'Unnamed: 0': 167,
#   'movieId': 198,
#   'title': 'Strange Days (1995)',
#   'movielens_genres': 'Action|Crime|Drama|Mystery|Sci-Fi|Thriller',
#   'avg_rating': 3.25,
#   'number_of_viewers': 28.0,
#   'imdbId': 114558,
#   'tmdbId': 281.0},
#  {'Unnamed: 0': 168,
#   'movieId': 199,
#   'title': 'Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)',
#   'movielens_genres': 'Drama|Musical|Romance',
#   'avg_rating': 4.125,
#   'number_of_viewers': 4.0,
#   'imdbId': 58450,
#   'tmdbId': 5967.0},
#  {'Unnamed: 0': 169,
#   'movieId': 201,
#   'title': 'Three Wishes (1995)',
#   'movielens_genres': 'Drama|Fantasy',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 114663,
#   'tmdbId': 47939.0},
#  {'Unnamed: 0': 170,
#   'movieId': 202,
#   'title': 'Total Eclipse (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 114702,
#   'tmdbId': 36834.0},
#  {'Unnamed: 0': 171,
#   'movieId': 203,
#   'title': 'To Wong Foo, Thanks for Everything! Julie Newmar (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.4318181818181817,
#   'number_of_viewers': 22.0,
#   'imdbId': 114682,
#   'tmdbId': 9090.0},
#  {'Unnamed: 0': 172,
#   'movieId': 204,
#   'title': 'Under Siege 2: Dark Territory (1995)',
#   'movielens_genres': 'Action',
#   'avg_rating': 2.716666666666667,
#   'number_of_viewers': 30.0,
#   'imdbId': 114781,
#   'tmdbId': 3512.0},
#  {'Unnamed: 0': 173,
#   'movieId': 205,
#   'title': 'Unstrung Heroes (1995)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.1666666666666665,
#   'number_of_viewers': 9.0,
#   'imdbId': 114798,
#   'tmdbId': 52856.0},
#  {'Unnamed: 0': 174,
#   'movieId': 206,
#   'title': 'Unzipped (1995)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 3.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 114805,
#   'tmdbId': 77350.0},
#  {'Unnamed: 0': 175,
#   'movieId': 207,
#   'title': 'Walk in the Clouds, A (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.4285714285714284,
#   'number_of_viewers': 21.0,
#   'imdbId': 114887,
#   'tmdbId': 9560.0},
#  {'Unnamed: 0': 176,
#   'movieId': 208,
#   'title': 'Waterworld (1995)',
#   'movielens_genres': 'Action|Adventure|Sci-Fi',
#   'avg_rating': 2.9130434782608696,
#   'number_of_viewers': 115.0,
#   'imdbId': 114898,
#   'tmdbId': 9804.0},
#  {'Unnamed: 0': 177,
#   'movieId': 209,
#   'title': "White Man's Burden (1995)",
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.1666666666666665,
#   'number_of_viewers': 3.0,
#   'imdbId': 114928,
#   'tmdbId': 31611.0},
#  {'Unnamed: 0': 178,
#   'movieId': 210,
#   'title': 'Wild Bill (1995)',
#   'movielens_genres': 'Western',
#   'avg_rating': 3.0,
#   'number_of_viewers': 4.0,
#   'imdbId': 114938,
#   'tmdbId': 65796.0},
#  {'Unnamed: 0': 179,
#   'movieId': 211,
#   'title': 'Browning Version, The (1994)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.5,
#   'number_of_viewers': 2.0,
#   'imdbId': 109340,
#   'tmdbId': 49805.0},
#  {'Unnamed: 0': 180,
#   'movieId': 212,
#   'title': 'Bushwhacked (1995)',
#   'movielens_genres': 'Adventure|Comedy|Crime|Mystery',
#   'avg_rating': 3.0,
#   'number_of_viewers': 3.0,
#   'imdbId': 112602,
#   'tmdbId': 26258.0},
#  {'Unnamed: 0': 181,
#   'movieId': 213,
#   'title': 'Burnt by the Sun (Utomlyonnye solntsem) (1994)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.8333333333333335,
#   'number_of_viewers': 6.0,
#   'imdbId': 111579,
#   'tmdbId': 50797.0},
#  {'Unnamed: 0': 182,
#   'movieId': 214,
#   'title': 'Before the Rain (Pred dozhdot) (1994)',
#   'movielens_genres': 'Drama|War',
#   'avg_rating': 4.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 110882,
#   'tmdbId': 19155.0},
#  {'Unnamed: 0': 183,
#   'movieId': 215,
#   'title': 'Before Sunrise (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 4.041666666666667,
#   'number_of_viewers': 24.0,
#   'imdbId': 112471,
#   'tmdbId': 76.0},
#  {'Unnamed: 0': 184,
#   'movieId': 216,
#   'title': 'Billy Madison (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.326530612244898,
#   'number_of_viewers': 49.0,
#   'imdbId': 112508,
#   'tmdbId': 11017.0},
#  {'Unnamed: 0': 185,
#   'movieId': 217,
#   'title': 'Babysitter, The (1995)',
#   'movielens_genres': 'Drama|Thriller',
#   'avg_rating': 2.3333333333333335,
#   'number_of_viewers': 6.0,
#   'imdbId': 112438,
#   'tmdbId': 37141.0},
#  {'Unnamed: 0': 186,
#   'movieId': 218,
#   'title': 'Boys on the Side (1995)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.4285714285714284,
#   'number_of_viewers': 14.0,
#   'imdbId': 112571,
#   'tmdbId': 9382.0},
#  {'Unnamed: 0': 187,
#   'movieId': 219,
#   'title': 'Cure, The (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 112757,
#   'tmdbId': 6715.0},
#  {'Unnamed: 0': 188,
#   'movieId': 220,
#   'title': 'Castle Freak (1995)',
#   'movielens_genres': 'Horror',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 112643,
#   'tmdbId': 18256.0},
#  {'Unnamed: 0': 189,
#   'movieId': 222,
#   'title': 'Circle of Friends (1995)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.75,
#   'number_of_viewers': 16.0,
#   'imdbId': 112679,
#   'tmdbId': 22625.0},
#  {'Unnamed: 0': 190,
#   'movieId': 223,
#   'title': 'Clerks (1994)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.855769230769231,
#   'number_of_viewers': 104.0,
#   'imdbId': 109445,
#   'tmdbId': 2292.0},
#  {'Unnamed: 0': 191,
#   'movieId': 224,
#   'title': 'Don Juan DeMarco (1995)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 3.6125,
#   'number_of_viewers': 40.0,
#   'imdbId': 112883,
#   'tmdbId': 1909.0},
#  {'Unnamed: 0': 192,
#   'movieId': 225,
#   'title': 'Disclosure (1994)',
#   'movielens_genres': 'Drama|Thriller',
#   'avg_rating': 3.5384615384615383,
#   'number_of_viewers': 52.0,
#   'imdbId': 109635,
#   'tmdbId': 8984.0},
#  {'Unnamed: 0': 193,
#   'movieId': 227,
#   'title': 'Drop Zone (1994)',
#   'movielens_genres': 'Action|Thriller',
#   'avg_rating': 2.863636363636364,
#   'number_of_viewers': 22.0,
#   'imdbId': 109676,
#   'tmdbId': 4954.0},
#  {'Unnamed: 0': 194,
#   'movieId': 228,
#   'title': 'Destiny Turns on the Radio (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.3333333333333335,
#   'number_of_viewers': 3.0,
#   'imdbId': 112854,
#   'tmdbId': 62488.0},
#  {'Unnamed: 0': 195,
#   'movieId': 229,
#   'title': 'Death and the Maiden (1994)',
#   'movielens_genres': 'Drama|Thriller',
#   'avg_rating': 3.4285714285714284,
#   'number_of_viewers': 7.0,
#   'imdbId': 109579,
#   'tmdbId': 10531.0},
#  {'Unnamed: 0': 196,
#   'movieId': 230,
#   'title': 'Dolores Claiborne (1995)',
#   'movielens_genres': 'Drama|Thriller',
#   'avg_rating': 3.3958333333333335,
#   'number_of_viewers': 24.0,
#   'imdbId': 109642,
#   'tmdbId': 11929.0},
#  {'Unnamed: 0': 197,
#   'movieId': 231,
#   'title': 'Dumb & Dumber (Dumb and Dumber) (1994)',
#   'movielens_genres': 'Adventure|Comedy',
#   'avg_rating': 3.0601503759398496,
#   'number_of_viewers': 133.0,
#   'imdbId': 109686,
#   'tmdbId': 8467.0},
#  {'Unnamed: 0': 198,
#   'movieId': 232,
#   'title': 'Eat Drink Man Woman (Yin shi nan nu) (1994)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 3.892857142857143,
#   'number_of_viewers': 14.0,
#   'imdbId': 111797,
#   'tmdbId': 10451.0},
#  {'Unnamed: 0': 199,
#   'movieId': 233,
#   'title': 'Exotica (1994)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.5,
#   'number_of_viewers': 12.0,
#   'imdbId': 109759,
#   'tmdbId': 20156.0},
#  {'Unnamed: 0': 200,
#   'movieId': 234,
#   'title': 'Exit to Eden (1994)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.588235294117647,
#   'number_of_viewers': 17.0,
#   'imdbId': 109758,
#   'tmdbId': 18395.0},
#  {'Unnamed: 0': 201,
#   'movieId': 235,
#   'title': 'Ed Wood (1994)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.678571428571429,
#   'number_of_viewers': 70.0,
#   'imdbId': 109707,
#   'tmdbId': 522.0},
#  {'Unnamed: 0': 202,
#   'movieId': 236,
#   'title': 'French Kiss (1995)',
#   'movielens_genres': 'Action|Comedy|Romance',
#   'avg_rating': 3.477777777777778,
#   'number_of_viewers': 45.0,
#   'imdbId': 113117,
#   'tmdbId': 397.0},
#  {'Unnamed: 0': 203,
#   'movieId': 237,
#   'title': 'Forget Paris (1995)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.340909090909091,
#   'number_of_viewers': 22.0,
#   'imdbId': 113097,
#   'tmdbId': 10525.0},
#  {'Unnamed: 0': 204,
#   'movieId': 238,
#   'title': 'Far From Home: The Adventures of Yellow Dog (1995)',
#   'movielens_genres': 'Adventure|Children',
#   'avg_rating': 4.0,
#   'number_of_viewers': 2.0,
#   'imdbId': 113028,
#   'tmdbId': 27985.0},
#  {'Unnamed: 0': 205,
#   'movieId': 239,
#   'title': 'Goofy Movie, A (1995)',
#   'movielens_genres': 'Animation|Children|Comedy|Romance',
#   'avg_rating': 3.0,
#   'number_of_viewers': 17.0,
#   'imdbId': 113198,
#   'tmdbId': 15789.0},
#  {'Unnamed: 0': 206,
#   'movieId': 240,
#   'title': 'Hideaway (1995)',
#   'movielens_genres': 'Thriller',
#   'avg_rating': 2.375,
#   'number_of_viewers': 4.0,
#   'imdbId': 113303,
#   'tmdbId': 27303.0},
#  {'Unnamed: 0': 207,
#   'movieId': 241,
#   'title': 'Fluke (1995)',
#   'movielens_genres': 'Children|Drama',
#   'avg_rating': 4.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 113089,
#   'tmdbId': 21183.0},
#  {'Unnamed: 0': 208,
#   'movieId': 242,
#   'title': 'Farinelli: il castrato (1994)',
#   'movielens_genres': 'Drama|Musical',
#   'avg_rating': 3.6,
#   'number_of_viewers': 5.0,
#   'imdbId': 109771,
#   'tmdbId': 10954.0},
#  {'Unnamed: 0': 209,
#   'movieId': 243,
#   'title': 'Gordy (1995)',
#   'movielens_genres': 'Children|Comedy|Fantasy',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 113199,
#   'tmdbId': 47867.0},
#  {'Unnamed: 0': 210,
#   'movieId': 246,
#   'title': 'Hoop Dreams (1994)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 4.293103448275862,
#   'number_of_viewers': 29.0,
#   'imdbId': 110057,
#   'tmdbId': 14275.0},
#  {'Unnamed: 0': 211,
#   'movieId': 247,
#   'title': 'Heavenly Creatures (1994)',
#   'movielens_genres': 'Crime|Drama',
#   'avg_rating': 3.928571428571429,
#   'number_of_viewers': 21.0,
#   'imdbId': 110005,
#   'tmdbId': 1024.0},
#  {'Unnamed: 0': 212,
#   'movieId': 248,
#   'title': 'Houseguest (1994)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.176470588235294,
#   'number_of_viewers': 17.0,
#   'imdbId': 110066,
#   'tmdbId': 17207.0},
#  {'Unnamed: 0': 213,
#   'movieId': 249,
#   'title': 'Immortal Beloved (1994)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.7222222222222223,
#   'number_of_viewers': 18.0,
#   'imdbId': 110116,
#   'tmdbId': 13701.0},
#  {'Unnamed: 0': 214,
#   'movieId': 250,
#   'title': 'Heavyweights (Heavy Weights) (1995)',
#   'movielens_genres': 'Children|Comedy',
#   'avg_rating': 2.5,
#   'number_of_viewers': 6.0,
#   'imdbId': 110006,
#   'tmdbId': 14819.0},
#  {'Unnamed: 0': 215,
#   'movieId': 251,
#   'title': 'Hunted, The (1995)',
#   'movielens_genres': 'Action',
#   'avg_rating': 3.0,
#   'number_of_viewers': 3.0,
#   'imdbId': 113360,
#   'tmdbId': 32631.0},
#  {'Unnamed: 0': 216,
#   'movieId': 252,
#   'title': 'I.Q. (1994)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.453488372093023,
#   'number_of_viewers': 43.0,
#   'imdbId': 110099,
#   'tmdbId': 11777.0},
#  {'Unnamed: 0': 217,
#   'movieId': 253,
#   'title': 'Interview with the Vampire: The Vampire Chronicles (1994)',
#   'movielens_genres': 'Drama|Horror',
#   'avg_rating': 3.458715596330275,
#   'number_of_viewers': 109.0,
#   'imdbId': 110148,
#   'tmdbId': 628.0},
#  {'Unnamed: 0': 218,
#   'movieId': 254,
#   'title': 'Jefferson in Paris (1995)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.0,
#   'number_of_viewers': 1.0,
#   'imdbId': 113463,
#   'tmdbId': 87729.0},
#  {'Unnamed: 0': 219,
#   'movieId': 255,
#   'title': 'Jerky Boys, The (1995)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 2.0714285714285716,
#   'number_of_viewers': 7.0,
#   'imdbId': 110189,
#   'tmdbId': 18713.0},
#  {'Unnamed: 0': 220,
#   'movieId': 256,
#   'title': 'Junior (1994)',
#   'movielens_genres': 'Comedy|Sci-Fi',
#   'avg_rating': 2.8285714285714287,
#   'number_of_viewers': 35.0,
#   'imdbId': 110216,
#   'tmdbId': 6280.0},
#  {'Unnamed: 0': 221,
# ...
#   'movieId': 1227,
#   'title': 'Once Upon a Time in America (1984)',
#   'movielens_genres': 'Crime|Drama',
#   'avg_rating': 4.0625,
#   'number_of_viewers': 16.0,
#   'imdbId': 87843,
#   'tmdbId': 311.0},
#  {'Unnamed: 0': 929,
#   'movieId': 1228,
#   'title': 'Raging Bull (1980)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 4.1875,
#   'number_of_viewers': 40.0,
#   'imdbId': 81398,
#   'tmdbId': 1578.0},
#  {'Unnamed: 0': 930,
#   'movieId': 1230,
#   'title': 'Annie Hall (1977)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.8706896551724137,
#   'number_of_viewers': 58.0,
#   'imdbId': 75686,
#   'tmdbId': 703.0},
#  {'Unnamed: 0': 931,
#   'movieId': 1231,
#   'title': 'Right Stuff, The (1983)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.863636363636364,
#   'number_of_viewers': 22.0,
#   'imdbId': 86197,
#   'tmdbId': 9549.0},
#  {'Unnamed: 0': 932,
#   'movieId': 1232,
#   'title': 'Stalker (1979)',
#   'movielens_genres': 'Drama|Mystery|Sci-Fi',
#   'avg_rating': 3.625,
#   'number_of_viewers': 8.0,
#   'imdbId': 79944,
#   'tmdbId': 1398.0},
#  {'Unnamed: 0': 933,
#   'movieId': 1233,
#   'title': 'Boot, Das (Boat, The) (1981)',
#   'movielens_genres': 'Action|Drama|War',
#   'avg_rating': 4.2125,
#   'number_of_viewers': 40.0,
#   'imdbId': 82096,
#   'tmdbId': 387.0},
#  {'Unnamed: 0': 934,
#   'movieId': 1234,
#   'title': 'Sting, The (1973)',
#   'movielens_genres': 'Comedy|Crime',
#   'avg_rating': 3.9765625,
#   'number_of_viewers': 64.0,
#   'imdbId': 70735,
#   'tmdbId': 9277.0},
#  {'Unnamed: 0': 935,
#   'movieId': 1235,
#   'title': 'Harold and Maude (1971)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 4.288461538461538,
#   'number_of_viewers': 26.0,
#   'imdbId': 67185,
#   'tmdbId': 343.0},
#  {'Unnamed: 0': 936,
#   'movieId': 1236,
#   'title': 'Trust (1990)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 4.333333333333333,
#   'number_of_viewers': 3.0,
#   'imdbId': 103130,
#   'tmdbId': 37291.0},
#  {'Unnamed: 0': 937,
#   'movieId': 1237,
#   'title': 'Seventh Seal, The (Sjunde inseglet, Det) (1957)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 4.222222222222222,
#   'number_of_viewers': 18.0,
#   'imdbId': 50976,
#   'tmdbId': 490.0},
#  {'Unnamed: 0': 938,
#   'movieId': 1238,
#   'title': 'Local Hero (1983)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 4.055555555555555,
#   'number_of_viewers': 9.0,
#   'imdbId': 85859,
#   'tmdbId': 11235.0},
#  {'Unnamed: 0': 939,
#   'movieId': 1240,
#   'title': 'Terminator, The (1984)',
#   'movielens_genres': 'Action|Sci-Fi|Thriller',
#   'avg_rating': 3.896946564885496,
#   'number_of_viewers': 131.0,
#   'imdbId': 88247,
#   'tmdbId': 218.0},
#  {'Unnamed: 0': 940,
#   'movieId': 1241,
#   'title': 'Dead Alive (Braindead) (1992)',
#   'movielens_genres': 'Comedy|Fantasy|Horror',
#   'avg_rating': 4.05,
#   'number_of_viewers': 10.0,
#   'imdbId': 103873,
#   'tmdbId': 763.0},
#  {'Unnamed: 0': 941,
#   'movieId': 1242,
#   'title': 'Glory (1989)',
#   'movielens_genres': 'Drama|War',
#   'avg_rating': 4.170731707317073,
#   'number_of_viewers': 41.0,
#   'imdbId': 97441,
#   'tmdbId': 9665.0},
#  {'Unnamed: 0': 942,
#   'movieId': 1243,
#   'title': 'Rosencrantz and Guildenstern Are Dead (1990)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.96875,
#   'number_of_viewers': 16.0,
#   'imdbId': 100519,
#   'tmdbId': 18971.0},
#  {'Unnamed: 0': 943,
#   'movieId': 1244,
#   'title': 'Manhattan (1979)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 4.106060606060606,
#   'number_of_viewers': 33.0,
#   'imdbId': 79522,
#   'tmdbId': 696.0},
#  {'Unnamed: 0': 944,
#   'movieId': 1245,
#   'title': "Miller's Crossing (1990)",
#   'movielens_genres': 'Crime|Drama|Film-Noir|Thriller',
#   'avg_rating': 4.225,
#   'number_of_viewers': 20.0,
#   'imdbId': 100150,
#   'tmdbId': 379.0},
#  {'Unnamed: 0': 945,
#   'movieId': 1246,
#   'title': 'Dead Poets Society (1989)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.9593023255813953,
#   'number_of_viewers': 86.0,
#   'imdbId': 97165,
#   'tmdbId': 207.0},
#  {'Unnamed: 0': 946,
#   'movieId': 1247,
#   'title': 'Graduate, The (1967)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 4.063291139240507,
#   'number_of_viewers': 79.0,
#   'imdbId': 61722,
#   'tmdbId': 37247.0},
#  {'Unnamed: 0': 947,
#   'movieId': 1248,
#   'title': 'Touch of Evil (1958)',
#   'movielens_genres': 'Crime|Film-Noir|Thriller',
#   'avg_rating': 4.264705882352941,
#   'number_of_viewers': 17.0,
#   'imdbId': 52311,
#   'tmdbId': 1480.0},
#  {'Unnamed: 0': 948,
#   'movieId': 1249,
#   'title': 'Femme Nikita, La (Nikita) (1990)',
#   'movielens_genres': 'Action|Crime|Romance|Thriller',
#   'avg_rating': 4.071428571428571,
#   'number_of_viewers': 35.0,
#   'imdbId': 100263,
#   'tmdbId': 9322.0},
#  {'Unnamed: 0': 949,
#   'movieId': 1250,
#   'title': 'Bridge on the River Kwai, The (1957)',
#   'movielens_genres': 'Adventure|Drama|War',
#   'avg_rating': 4.122222222222222,
#   'number_of_viewers': 45.0,
#   'imdbId': 50212,
#   'tmdbId': 826.0},
#  {'Unnamed: 0': 950,
#   'movieId': 1251,
#   'title': '8 1/2 (8½) (1963)',
#   'movielens_genres': 'Drama|Fantasy',
#   'avg_rating': 4.071428571428571,
#   'number_of_viewers': 14.0,
#   'imdbId': 56801,
#   'tmdbId': 422.0},
#  {'Unnamed: 0': 951,
#   'movieId': 1252,
#   'title': 'Chinatown (1974)',
#   'movielens_genres': 'Crime|Film-Noir|Mystery|Thriller',
#   'avg_rating': 4.211864406779661,
#   'number_of_viewers': 59.0,
#   'imdbId': 71315,
#   'tmdbId': 829.0},
#  {'Unnamed: 0': 952,
#   'movieId': 1253,
#   'title': 'Day the Earth Stood Still, The (1951)',
#   'movielens_genres': 'Drama|Sci-Fi|Thriller',
#   'avg_rating': 3.82,
#   'number_of_viewers': 25.0,
#   'imdbId': 43456,
#   'tmdbId': 828.0},
#  {'Unnamed: 0': 953,
#   'movieId': 1254,
#   'title': 'Treasure of the Sierra Madre, The (1948)',
#   'movielens_genres': 'Action|Adventure|Drama|Western',
#   'avg_rating': 3.65625,
#   'number_of_viewers': 16.0,
#   'imdbId': 40897,
#   'tmdbId': 3090.0},
#  {'Unnamed: 0': 954,
#   'movieId': 1255,
#   'title': 'Bad Taste (1987)',
#   'movielens_genres': 'Comedy|Horror|Sci-Fi',
#   'avg_rating': 3.0,
#   'number_of_viewers': 6.0,
#   'imdbId': 92610,
#   'tmdbId': 9964.0},
#  {'Unnamed: 0': 955,
#   'movieId': 1256,
#   'title': 'Duck Soup (1933)',
#   'movielens_genres': 'Comedy|Musical|War',
#   'avg_rating': 3.804347826086957,
#   'number_of_viewers': 23.0,
#   'imdbId': 23969,
#   'tmdbId': 3063.0},
#  {'Unnamed: 0': 956,
#   'movieId': 1257,
#   'title': 'Better Off Dead... (1985)',
#   'movielens_genres': 'Comedy|Romance',
#   'avg_rating': 3.685185185185185,
#   'number_of_viewers': 27.0,
#   'imdbId': 88794,
#   'tmdbId': 13667.0},
#  {'Unnamed: 0': 957,
#   'movieId': 1258,
#   'title': 'Shining, The (1980)',
#   'movielens_genres': 'Horror',
#   'avg_rating': 4.082568807,
#   'number_of_viewers': 109.0,
#   'imdbId': 81505,
#   'tmdbId': 694.0},
#  {'Unnamed: 0': 958,
#   'movieId': 1259,
#   'title': 'Stand by Me (1986)',
#   'movielens_genres': 'Adventure|Drama',
#   'avg_rating': 4.0054945054945055,
#   'number_of_viewers': 91.0,
#   'imdbId': 92005,
#   'tmdbId': 235.0},
#  {'Unnamed: 0': 959,
#   'movieId': 1260,
#   'title': 'M (1931)',
#   'movielens_genres': 'Crime|Film-Noir|Thriller',
#   'avg_rating': 3.7333333333333334,
#   'number_of_viewers': 15.0,
#   'imdbId': 22100,
#   'tmdbId': 832.0},
#  {'Unnamed: 0': 960,
#   'movieId': 1261,
#   'title': 'Evil Dead II (Dead by Dawn) (1987)',
#   'movielens_genres': 'Action|Comedy|Fantasy|Horror',
#   'avg_rating': 4.044117647058823,
#   'number_of_viewers': 34.0,
#   'imdbId': 92991,
#   'tmdbId': 765.0},
#  {'Unnamed: 0': 961,
#   'movieId': 1262,
#   'title': 'Great Escape, The (1963)',
#   'movielens_genres': 'Action|Adventure|Drama|War',
#   'avg_rating': 4.127906976744186,
#   'number_of_viewers': 43.0,
#   'imdbId': 57115,
#   'tmdbId': 5925.0},
#  {'Unnamed: 0': 962,
#   'movieId': 1263,
#   'title': 'Deer Hunter, The (1978)',
#   'movielens_genres': 'Drama|War',
#   'avg_rating': 3.825581395348838,
#   'number_of_viewers': 43.0,
#   'imdbId': 77416,
#   'tmdbId': 11778.0},
#  {'Unnamed: 0': 963,
#   'movieId': 1264,
#   'title': 'Diva (1981)',
#   'movielens_genres': 'Action|Drama|Mystery|Romance|Thriller',
#   'avg_rating': 3.8,
#   'number_of_viewers': 5.0,
#   'imdbId': 82269,
#   'tmdbId': 4485.0},
#  {'Unnamed: 0': 964,
#   'movieId': 1265,
#   'title': 'Groundhog Day (1993)',
#   'movielens_genres': 'Comedy|Fantasy|Romance',
#   'avg_rating': 3.944055944055944,
#   'number_of_viewers': 143.0,
#   'imdbId': 107048,
#   'tmdbId': 137.0},
#  {'Unnamed: 0': 965,
#   'movieId': 1266,
#   'title': 'Unforgiven (1992)',
#   'movielens_genres': 'Drama|Western',
#   'avg_rating': 4.111111111111111,
#   'number_of_viewers': 45.0,
#   'imdbId': 105695,
#   'tmdbId': 33.0},
#  {'Unnamed: 0': 966,
#   'movieId': 1267,
#   'title': 'Manchurian Candidate, The (1962)',
#   'movielens_genres': 'Crime|Thriller|War',
#   'avg_rating': 4.25,
#   'number_of_viewers': 30.0,
#   'imdbId': 56218,
#   'tmdbId': 982.0},
#  {'Unnamed: 0': 967,
#   'movieId': 1268,
#   'title': 'Pump Up the Volume (1990)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.611111111111111,
#   'number_of_viewers': 9.0,
#   'imdbId': 100436,
#   'tmdbId': 8428.0},
#  {'Unnamed: 0': 968,
#   'movieId': 1269,
#   'title': 'Arsenic and Old Lace (1944)',
#   'movielens_genres': 'Comedy|Mystery|Thriller',
#   'avg_rating': 3.8793103448275863,
#   'number_of_viewers': 29.0,
#   'imdbId': 36613,
#   'tmdbId': 212.0},
#  {'Unnamed: 0': 969,
#   'movieId': 1270,
#   'title': 'Back to the Future (1985)',
#   'movielens_genres': 'Adventure|Comedy|Sci-Fi',
#   'avg_rating': 4.038011695906433,
#   'number_of_viewers': 171.0,
#   'imdbId': 88763,
#   'tmdbId': 105.0},
#  {'Unnamed: 0': 970,
#   'movieId': 1271,
#   'title': 'Fried Green Tomatoes (1991)',
#   'movielens_genres': 'Comedy|Crime|Drama',
#   'avg_rating': 3.5,
#   'number_of_viewers': 30.0,
#   'imdbId': 101921,
#   'tmdbId': 1633.0},
#  {'Unnamed: 0': 971,
#   'movieId': 1272,
#   'title': 'Patton (1970)',
#   'movielens_genres': 'Drama|War',
#   'avg_rating': 4.121212121212121,
#   'number_of_viewers': 33.0,
#   'imdbId': 66206,
#   'tmdbId': 11202.0},
#  {'Unnamed: 0': 972,
#   'movieId': 1273,
#   'title': 'Down by Law (1986)',
#   'movielens_genres': 'Comedy|Drama|Film-Noir',
#   'avg_rating': 4.045454545454546,
#   'number_of_viewers': 11.0,
#   'imdbId': 90967,
#   'tmdbId': 1554.0},
#  {'Unnamed: 0': 973,
#   'movieId': 1274,
#   'title': 'Akira (1988)',
#   'movielens_genres': 'Action|Adventure|Animation|Sci-Fi',
#   'avg_rating': 3.743589743589744,
#   'number_of_viewers': 39.0,
#   'imdbId': 94625,
#   'tmdbId': 149.0},
#  {'Unnamed: 0': 974,
#   'movieId': 1275,
#   'title': 'Highlander (1986)',
#   'movielens_genres': 'Action|Adventure|Fantasy',
#   'avg_rating': 3.7291666666666665,
#   'number_of_viewers': 48.0,
#   'imdbId': 91203,
#   'tmdbId': 8009.0},
#  {'Unnamed: 0': 975,
#   'movieId': 1276,
#   'title': 'Cool Hand Luke (1967)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 4.271929824561403,
#   'number_of_viewers': 57.0,
#   'imdbId': 61512,
#   'tmdbId': 903.0},
#  {'Unnamed: 0': 976,
#   'movieId': 1277,
#   'title': 'Cyrano de Bergerac (1990)',
#   'movielens_genres': 'Comedy|Drama|Romance',
#   'avg_rating': 4.125,
#   'number_of_viewers': 12.0,
#   'imdbId': 99334,
#   'tmdbId': 11673.0},
#  {'Unnamed: 0': 977,
#   'movieId': 1278,
#   'title': 'Young Frankenstein (1974)',
#   'movielens_genres': 'Comedy|Fantasy',
#   'avg_rating': 3.9927536231884058,
#   'number_of_viewers': 69.0,
#   'imdbId': 72431,
#   'tmdbId': 3034.0},
#  {'Unnamed: 0': 978,
#   'movieId': 1279,
#   'title': 'Night on Earth (1991)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 4.125,
#   'number_of_viewers': 8.0,
#   'imdbId': 102536,
#   'tmdbId': 339.0},
#  {'Unnamed: 0': 979,
#   'movieId': 1280,
#   'title': 'Raise the Red Lantern (Da hong deng long gao gao gua) (1991)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 4.333333333333333,
#   'number_of_viewers': 9.0,
#   'imdbId': 101640,
#   'tmdbId': 10404.0},
#  {'Unnamed: 0': 980,
#   'movieId': 1281,
#   'title': 'Great Dictator, The (1940)',
#   'movielens_genres': 'Comedy|Drama|War',
#   'avg_rating': 4.133333333333334,
#   'number_of_viewers': 15.0,
#   'imdbId': 32553,
#   'tmdbId': 914.0},
#  {'Unnamed: 0': 981,
#   'movieId': 1282,
#   'title': 'Fantasia (1940)',
#   'movielens_genres': 'Animation|Children|Fantasy|Musical',
#   'avg_rating': 3.783018867924529,
#   'number_of_viewers': 53.0,
#   'imdbId': 32455,
#   'tmdbId': 756.0},
#  {'Unnamed: 0': 982,
#   'movieId': 1283,
#   'title': 'High Noon (1952)',
#   'movielens_genres': 'Drama|Western',
#   'avg_rating': 4.2105263157894735,
#   'number_of_viewers': 19.0,
#   'imdbId': 44706,
#   'tmdbId': 288.0},
#  {'Unnamed: 0': 983,
#   'movieId': 1284,
#   'title': 'Big Sleep, The (1946)',
#   'movielens_genres': 'Crime|Film-Noir|Mystery',
#   'avg_rating': 4.142857142857143,
#   'number_of_viewers': 14.0,
#   'imdbId': 38355,
#   'tmdbId': 910.0},
#  {'Unnamed: 0': 984,
#   'movieId': 1285,
#   'title': 'Heathers (1989)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.731707317073171,
#   'number_of_viewers': 41.0,
#   'imdbId': 97493,
#   'tmdbId': 2640.0},
#  {'Unnamed: 0': 985,
#   'movieId': 1286,
#   'title': 'Somewhere in Time (1980)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.0714285714285716,
#   'number_of_viewers': 7.0,
#   'imdbId': 81534,
#   'tmdbId': 16633.0},
#  {'Unnamed: 0': 986,
#   'movieId': 1287,
#   'title': 'Ben-Hur (1959)',
#   'movielens_genres': 'Action|Adventure|Drama',
#   'avg_rating': 3.941176470588235,
#   'number_of_viewers': 34.0,
#   'imdbId': 52618,
#   'tmdbId': 665.0},
#  {'Unnamed: 0': 987,
#   'movieId': 1288,
#   'title': 'This Is Spinal Tap (1984)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 4.015151515151516,
#   'number_of_viewers': 66.0,
#   'imdbId': 88258,
#   'tmdbId': 11031.0},
#  {'Unnamed: 0': 988,
#   'movieId': 1289,
#   'title': 'Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983)',
#   'movielens_genres': 'Documentary',
#   'avg_rating': 3.863636363636364,
#   'number_of_viewers': 11.0,
#   'imdbId': 85809,
#   'tmdbId': 11314.0},
#  {'Unnamed: 0': 989,
#   'movieId': 1290,
#   'title': 'Some Kind of Wonderful (1987)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.35,
#   'number_of_viewers': 10.0,
#   'imdbId': 94006,
#   'tmdbId': 15143.0},
#  {'Unnamed: 0': 990,
#   'movieId': 1291,
#   'title': 'Indiana Jones and the Last Crusade (1989)',
#   'movielens_genres': 'Action|Adventure',
#   'avg_rating': 4.046428571428572,
#   'number_of_viewers': 140.0,
#   'imdbId': 97576,
#   'tmdbId': 89.0},
#  {'Unnamed: 0': 991,
#   'movieId': 1292,
#   'title': 'Being There (1979)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 3.95,
#   'number_of_viewers': 20.0,
#   'imdbId': 78841,
#   'tmdbId': 10322.0},
#  {'Unnamed: 0': 992,
#   'movieId': 1293,
#   'title': 'Gandhi (1982)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.8333333333333335,
#   'number_of_viewers': 27.0,
#   'imdbId': 83987,
#   'tmdbId': 783.0},
#  {'Unnamed: 0': 993,
#   'movieId': 1295,
#   'title': 'Unbearable Lightness of Being, The (1988)',
#   'movielens_genres': 'Drama',
#   'avg_rating': 3.227272727272727,
#   'number_of_viewers': 11.0,
#   'imdbId': 96332,
#   'tmdbId': 10644.0},
#  {'Unnamed: 0': 994,
#   'movieId': 1296,
#   'title': 'Room with a View, A (1986)',
#   'movielens_genres': 'Drama|Romance',
#   'avg_rating': 3.7058823529411766,
#   'number_of_viewers': 17.0,
#   'imdbId': 91867,
#   'tmdbId': 11257.0},
#  {'Unnamed: 0': 995,
#   'movieId': 1297,
#   'title': 'Real Genius (1985)',
#   'movielens_genres': 'Comedy',
#   'avg_rating': 3.675,
#   'number_of_viewers': 20.0,
#   'imdbId': 89886,
#   'tmdbId': 14370.0},
#  {'Unnamed: 0': 996,
#   'movieId': 1298,
#   'title': 'Pink Floyd: The Wall (1982)',
#   'movielens_genres': 'Drama|Musical',
#   'avg_rating': 3.760869565217391,
#   'number_of_viewers': 23.0,
#   'imdbId': 84503,
#   'tmdbId': 12104.0},
#  {'Unnamed: 0': 997,
#   'movieId': 1299,
#   'title': 'Killing Fields, The (1984)',
#   'movielens_genres': 'Drama|War',
#   'avg_rating': 4.017857142857143,
#   'number_of_viewers': 28.0,
#   'imdbId': 87553,
#   'tmdbId': 625.0},
#  {'Unnamed: 0': 998,
#   'movieId': 1300,
#   'title': 'My Life as a Dog (Mitt liv som hund) (1985)',
#   'movielens_genres': 'Comedy|Drama',
#   'avg_rating': 4.166666666666667,
#   'number_of_viewers': 9.0,
#   'imdbId': 89606,
#   'tmdbId': 8816.0},
#  {'Unnamed: 0': 999,
#   'movieId': 1301,
#   'title': 'Forbidden Planet (1956)',
#   'movielens_genres': 'Drama|Sci-Fi',
#   'avg_rating': 3.807692307692307,
#   'number_of_viewers': 13.0,
#   'imdbId': 49223,
#   'tmdbId': 830.0},
#  ...]

# %%
#Process 1 1000 record
for row in range(0, min(1000, len(movie_abt_json))):
    tmdb_id = movie_abt_json[row]["tmdbId"]
    
    if pd.notna(tmdb_id):
        movie_id = int(float(tmdb_id))
        tmdb_json = load_tmdb_data(movie_id)
        
        for key in tmdb_json.keys():
            movie_abt_json[row][key] = tmdb_json[key]

# %%
#Process 1001-2000 record
for row in range(1000, min(2000, len(movie_abt_json))):
    tmdb_id = movie_abt_json[row]["tmdbId"]
    
    if pd.notna(tmdb_id):
        movie_id = int(float(tmdb_id))
        tmdb_json = load_tmdb_data(movie_id)
        
        for key in tmdb_json.keys():
            movie_abt_json[row][key] = tmdb_json[key]

# %%
#Process 8001-9000 record
for row in range(8000, min(9000, len(movie_abt_json))):
    tmdb_id = movie_abt_json[row]["tmdbId"]
    
    if pd.notna(tmdb_id):
        movie_id = int(float(tmdb_id))
        tmdb_json = load_tmdb_data(movie_id)
        
        for key in tmdb_json.keys():
            movie_abt_json[row][key] = tmdb_json[key]

# %%
df_enhanced_movie_abt = pd.DataFrame(movie_abt_json)
df_enhanced_movie_abt.to_csv("../data/outputs/analytics_base_table_enriched8001-9000.csv")

# %% [markdown]
# # Alaternative Batch upload

# %%
# Batch Processing + Save to Excel After Each Batch with time delay

batch_size = 1000
total_records = len(movie_abt_json)
output_file = "movie_abt_enriched.xlsx"
print(f"Total records: {total_records}")
for start in range(0, total_records, batch_size):
    end = min(start + batch_size, total_records)
    batch_number = start // batch_size + 1
    print(f"\nProcessing Batch {batch_number}: Records {start} to {end - 1}")
    for row in range(start, end):
        tmdb_id = movie_abt_json[row]["tmdbId"]     
        if pd.notna(tmdb_id):
            try:
                movie_id = int(float(tmdb_id))
                tmdb_json = load_tmdb_data(movie_id)
                
                for key in tmdb_json.keys():
                    movie_abt_json[row][key] = tmdb_json[key]               
                time.sleep(0.05)  # small delay to avoid API throttling             
            except Exception as e:
                print(f"Error at row {row}: {e}")   
    # ✅ Convert updated JSON back to DataFrame
    abt_df = pd.DataFrame(movie_abt_json) 
    # ✅ Save after each batch
    abt_df.to_excel(output_file, index=False)
    print(f"Batch {batch_number} completed and saved to Excel.")
print("\nAll batches completed successfully.")
# Out:
# Total records: 9742
#
# Processing Batch 1: Records 0 to 999
# Batch 1 completed and saved to Excel.
#
# Processing Batch 2: Records 1000 to 1999
# Batch 2 completed and saved to Excel.
#
# Processing Batch 3: Records 2000 to 2999
# Batch 3 completed and saved to Excel.
#
# Processing Batch 4: Records 3000 to 3999
# Batch 4 completed and saved to Excel.
#
# Processing Batch 5: Records 4000 to 4999
# Batch 5 completed and saved to Excel.
#
# Processing Batch 6: Records 5000 to 5999
# Batch 6 completed and saved to Excel.
#
# Processing Batch 7: Records 6000 to 6999
# Batch 7 completed and saved to Excel.
#
# Processing Batch 8: Records 7000 to 7999
# Batch 8 completed and saved to Excel.
#
# Processing Batch 9: Records 8000 to 8999
# Batch 9 completed and saved to Excel.
#
# Processing Batch 10: Records 9000 to 9741
# Batch 10 completed and saved to Excel.
#
# All batches completed successfully.

# %%
# Create consolidated ABT file

# Set folder path (change if needed)
folder_path = "..//data/outputs/ABT_Enriched"

# Get all CSV files matching your pattern
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

print("Files found:")
for file in csv_files:
    print(file)

# Read and combine
df_list = [pd.read_csv(file) for file in csv_files]
final_abt = pd.concat(df_list, ignore_index=True)
print("Total records after merge:", len(final_abt))
final_abt = final_abt.drop_duplicates(subset="movieId")
print("Total records after removing duplicates:", len(final_abt))
final_abt.to_excel("analytics_base_table_enriched_consolidated.xlsx", index=False)
print("Final consolidated Excel file created successfully.")
# Out:
# Files found:
# ..//data/outputs/ABT_Enriched/analytics_base_table_enrichedFirst1000.csv
# ..//data/outputs/ABT_Enriched/analytics_base_table_enriched7001-8000.csv
# ..//data/outputs/ABT_Enriched/analytics_base_table_enriched6001-7000.csv
# ..//data/outputs/ABT_Enriched/analytics_base_table_enriched1001-2000.csv
# ..//data/outputs/ABT_Enriched/movie_abt_enriched_final_batch.csv
# ..//data/outputs/ABT_Enriched/analytics_base_table_enriched3001-4000.csv
# ..//data/outputs/ABT_Enriched/analytics_base_table_enriched4001-5000.csv
# ..//data/outputs/ABT_Enriched/analytics_base_table_enriched2001-3000.csv
# ..//data/outputs/ABT_Enriched/analytics_base_table_enriched5001-6000.csv
# Total records after merge: 87678
# Total records after removing duplicates: 9742
# Final consolidated Excel file created successfully.

# %%
for row in range(0, len(movie_abt_json)):
    tmdb_id = movie_abt_json[row]["tmdbId"]
    if pd.notna(tmdb_id):
        movie_id = int(float(tmdb_id))
        tmdb_json = load_tmdb_data(movie_id)
        for key in tmdb_json.keys():
            movie_abt_json[row][key]=tmdb_json[key]
movie_abt_json[0]

# %% [markdown]
# ## Configuration

# %%
display_config()
# Out:
# ======================================================================
# API CONFIGURATION (.env file)
# ======================================================================
# LLM Provider:    openai
# LLM Model:       gpt-4.1-mini
# Temperature:     0.0
#
# API Keys Status:
#   OpenAI               ✓ Set
#   Google               ✗ Not set
#   Mistral              ✗ Not set
#   Anthropic            ✗ Not set
#   Serper (Web Search)  ✓ Set
# ======================================================================
#
# Data Files:
#   Provide file paths as function parameters
#   Example: load_use_case_config('your_file.xlsx')
# ======================================================================

# %% [markdown]
# ## Load Use Case

# %%
# Load use case configuration
use_case_file = "../data/input/use_case_Movie_Recommendation.xlsx"
use_case_config = load_use_case_config(use_case_file)
system_prompt = use_case_config.get("agent_prompt", "You are a helpful movie assistant")

print(f"✓ System prompt loaded")
# Out:
# ✓ Use case loaded: ../data/input/use_case_Movie_Recommendation.xlsx
#   Components: user, agent_prompt, url
# ✓ System prompt loaded

# %%
# Load ABT Data file
ABT_File= "../data/outputs/analytics_base_table_with_genres_list.csv"

df = pd.read_csv(ABT_File)

print(df.head)
# Out:
# <bound method NDFrame.head of       Unnamed: 0  movieId                                      title  \
# 0              0        1                           Toy Story (1995)
# 1              1        2                             Jumanji (1995)
# 2              2        3                    Grumpier Old Men (1995)
# 3              3        4                   Waiting to Exhale (1995)
# 4              4        5         Father of the Bride Part II (1995)
# ...          ...      ...                                        ...
# 9737        9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738        9738   193583               No Game No Life: Zero (2017)
# 9739        9739   193585                               Flint (2017)
# 9740        9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741        9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  avg rating   \
# 0     Adventure|Animation|Children|Comedy|Fantasy          3.9
# 1                      Adventure|Children|Fantasy          3.4
# 2                                  Comedy|Romance          3.3
# 3                            Comedy|Drama|Romance          2.4
# 4                                          Comedy          3.1
# ...                                           ...          ...
# 9737              Action|Animation|Comedy|Fantasy          4.0
# 9738                     Animation|Comedy|Fantasy          3.5
# 9739                                        Drama          3.5
# 9740                             Action|Animation          3.5
# 9741                                       Comedy          4.0
#
#       no of viewer rating                                   viewers tags  \
# 0                    215.0                               pixar|pixar|fun
# 1                    110.0  fantasy|magic board game|Robin Williams|game
# 2                     52.0                                     moldy|old
# 3                      7.0                                           NaN
# 4                     49.0                              pregnancy|remake
# ...                    ...                                           ...
# 9737                   1.0                                           NaN
# 9738                   1.0                                           NaN
# 9739                   1.0                                           NaN
# 9740                   1.0                                           NaN
# 9741                   1.0                                           NaN
#
#        imdbId    tmdbId                                        Genres_List
# 0      114709     862.0  ['Adventure', 'Animation', 'Children', 'Comedy...
# 1      113497    8844.0               ['Adventure', 'Children', 'Fantasy']
# 2      113228   15602.0                              ['Comedy', 'Romance']
# 3      114885   31357.0                     ['Comedy', 'Drama', 'Romance']
# 4      113041   11862.0                                         ['Comedy']
# ...       ...       ...                                                ...
# 9737  5476944  432131.0       ['Action', 'Animation', 'Comedy', 'Fantasy']
# 9738  5914996  445030.0                 ['Animation', 'Comedy', 'Fantasy']
# 9739  6397426  479308.0                                          ['Drama']
# 9740  8391976  483455.0                            ['Action', 'Animation']
# 9741   101726   37891.0                                         ['Comedy']
#
# [9742 rows x 10 columns]>

# %% [markdown]
# ## Extract URLs from Excel

# %%
# Extract URLs from use case file
url_string = use_case_config.get("url", "")

if url_string and url_string.strip():
    # Parse comma-separated URLs
    urls = [url.strip() for url in url_string.split(",") if url.strip()]
    print(f"✓ Found {len(urls)} URLs in use case file:")
    for i, url in enumerate(urls, 1):
        print(f"  {i}. {url}")
else:
    urls = []
    print("⚠️ No URLs found in use case file")
# Out:
# ✓ Found 3 URLs in use case file:
#   1. https://IMDB.com
#   2. https://www.themoviedb.org
#   3. https://grouplens.org/datasets/movielens/

# %% [markdown]
# ## Build Curated Knowledge Base from Excel URLs
#
# This creates a searchable knowledge base from the URLs in your Excel file.

# %%
url_retriever = None

if urls:
    try:
        print(f"\n📥 Loading content from {len(urls)} URLs...")
        
        # Load documents from URLs
        loader = WebBaseLoader(urls)
        documents = loader.load()
        print(f"  ✓ Loaded {len(documents)} documents")
        
        # Split into chunks
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,
            chunk_overlap=200
        )
        splits = text_splitter.split_documents(documents)
        print(f"  ✓ Created {len(splits)} text chunks")
        
        # Create vector store
        embeddings = OpenAIEmbeddings()
        vectorstore = FAISS.from_documents(splits, embeddings)
        print(f"  ✓ Vector store created")
        
        # Create retriever
        url_retriever = vectorstore.as_retriever(search_kwargs={"k": 3})
        print(f"  ✓ Retriever ready")
        
        print("\n✅ Curated knowledge base built from Excel URLs!")
        
    except Exception as e:
        print(f"\n❌ Error building knowledge base: {str(e)}")
        print("Tools will still work, but curated_knowledge_search will be limited")
        url_retriever = None
else:
    print("\n⚠️ Skipping knowledge base (no URLs in Excel)")
    print("You can still use search_web and fetch_url_content")
# Out:
# 📥 Loading content from 3 URLs...
#   ✓ Loaded 3 documents
#   ✓ Created 14 text chunks
#   ✓ Vector store created
#   ✓ Retriever ready
#
# ✅ Curated knowledge base built from Excel URLs!

# %% [markdown]
# ## Define Tools
#
# Three powerful tools for comprehensive movie information retrieval.

# %%
# Tool 1: General Web Search
@tool
def search_web(query: str) -> str:
    """
    Search the web for current movie information, news, and reviews.
    
    Best for:
    - Current information (box office, new releases)
    - General queries about movies
    - Recent news and reviews
    - When you need real-time data
    
    Args:
        query: Search query
        
    Returns:
        Search results from the web
    """
    try:
        search = GoogleSerperAPIWrapper()
        return search.run(query)
    except Exception as e:
        return f"Search error: {str(e)}"

print("✓ Tool 1: search_web defined")
# Out:
# ✓ Tool 1: search_web defined

# %%
# Tool 2: Curated Knowledge Search (from Excel URLs)
@tool
def curated_knowledge_search(query: str) -> str:
    """
    Search the curated knowledge base built from URLs in the Excel file.
    
    Best for:
    - Information from pre-loaded trusted sources
    - Queries about content in the configured URLs
    - Domain-specific knowledge from IMDB, TMDB, etc.
    
    Args:
        query: Search query
        
    Returns:
        Relevant content from curated sources
    """
    if url_retriever is None:
        return "Curated knowledge base not available. No URLs were loaded from Excel file."
    
    try:
        docs = url_retriever.invoke(query)
        results = []
        for doc in docs:
            source = doc.metadata.get('source', 'Unknown')
            content = doc.page_content
            results.append(f"Source: {source}\nContent: {content}")
        
        return "\n\n---\n\n".join(results)
    except Exception as e:
        return f"Error searching curated knowledge: {str(e)}"

print("✓ Tool 2: curated_knowledge_search defined")
# Out:
# ✓ Tool 2: curated_knowledge_search defined

# %%
# Tool 3: Dynamic URL Fetch 
@tool  
def fetch_url_content(url: str) -> str:
    """
    Fetch and extract content from any specific URL on-demand.
    
    Best for:
    - When user provides a specific URL (e.g., https://www.imdb.com/title/tt0113041)
    - Need fresh content from a specific webpage
    - Retrieving data from URLs not in the curated knowledge base
    - Ad-hoc queries about specific movie pages
    
    Args:
        url: Full URL to fetch (must include https:// or http://)
        
    Returns:
        Extracted text content from the URL
    
    Examples:
    - fetch_url_content("https://www.imdb.com/title/tt0113041")
    - fetch_url_content("https://www.themoviedb.org/movie/11862")
    """
    try:
        print(f"  🌐 Fetching: {url}")
        
        # Load the URL
        loader = WebBaseLoader([url])
        documents = loader.load()
        
        if documents:
            # Extract content (limit to 5000 chars to avoid token limits)
            content = documents[0].page_content[:5000]
            
            # Add metadata if available
            metadata = documents[0].metadata
            source_info = f"Source: {metadata.get('source', url)}"
            
            return f"{source_info}\n\nContent:\n{content}"
        else:
            return f"No content could be extracted from {url}"
            
    except Exception as e:
        return f"Error fetching {url}: {str(e)}\n\nPlease verify the URL is valid and accessible."

print("✓ Tool 3: fetch_url_content defined")
# Out:
# ✓ Tool 3: fetch_url_content defined

# %%
# Configure tools based on availability
if url_retriever is not None:
    tools = [search_web, curated_knowledge_search, fetch_url_content]
    print(f"\n✅ All 3 tools configured:")
    print("  1. search_web - General web search")
    print("  2. curated_knowledge_search - Pre-loaded URLs from Excel")
    print("  3. fetch_url_content - Dynamic URL fetching")
else:
    tools = [search_web, fetch_url_content]
    print(f"\n✅ 2 tools configured:")
    print("  1. search_web - General web search")
    print("  2. fetch_url_content - Dynamic URL fetching")
    print("  (curated_knowledge_search not available - no URLs in Excel)")
# Out:
# ✅ All 3 tools configured:
#   1. search_web - General web search
#   2. curated_knowledge_search - Pre-loaded URLs from Excel
#   3. fetch_url_content - Dynamic URL fetching

# %% [markdown]
# ## Initialize LLM

# %%
llm = load_llm_from_env()
model = llm.bind_tools(tools)

print("✓ LLM initialized with tools")
# Out:
# 🤖 Loading LLM: openai / gpt-4.1-mini
# ✓ LLM initialized with tools

# %% [markdown]
# ## Build Agent Graph with Memory

# %%
def call_model(state: MessagesState):
    """Agent node that decides which tools to use."""
    messages = [SystemMessage(content=system_prompt)] + state["messages"]
    return {"messages": [model.invoke(messages)]}

def should_continue(state: MessagesState):
    """Decision function: continue to tools or end."""
    last_message = state["messages"][-1]
    return "tools" if last_message.tool_calls else END

# Build workflow
workflow = StateGraph(MessagesState)
workflow.add_node("agent", call_model)
workflow.add_node("tools", ToolNode(tools))
workflow.set_entry_point("agent")
workflow.add_conditional_edges(
    "agent",
    should_continue,
    {"tools": "tools", END: END}
)
workflow.add_edge("tools", "agent")

# Compile with memory
app = workflow.compile(checkpointer=MemorySaver())

print("✓ Agent graph with memory compiled")
app = workflow.compile()
# Out:
# ✓ Agent graph with memory compiled

# %%
display(Image(app.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Chat Helper Function
#
# Use this to have conversations with the assistant.

# %%
def chat(user_input: str, thread_id: str = "default", verbose: bool = False) -> str:
    """
    Chat with the movie assistant.
    
    Args:
        user_input: Your message/query
        thread_id: Conversation thread ID (use same ID to continue conversation)
        verbose: Show which tools are being used
        
    Returns:
        Assistant's response
    """
    config = {"configurable": {"thread_id": thread_id}}
    
    if verbose:
        print(f"\n{'='*70}")
        print(f"Query: {user_input[:100]}...")
        print(f"{'='*70}")
        tools_used = []
    
    result = None
    for event in app.stream(
        {"messages": [HumanMessage(content=user_input)]},
        config,
        stream_mode="values"
    ):
        result = event
        if verbose:
            last_message = event["messages"][-1]
            if hasattr(last_message, 'tool_calls') and last_message.tool_calls:
                for tool_call in last_message.tool_calls:
                    tool_name = tool_call['name']
                    if tool_name not in tools_used:
                        tools_used.append(tool_name)
                        print(f"  🔧 Using: {tool_name}")
    
    if verbose and tools_used:
        print(f"  ✓ Tools used: {', '.join(tools_used)}")
    
    return result["messages"][-1].content

print("\n🎬 Movie Chatbot Ready!")
print("\nUsage:")
print("  response = chat('Your question')")
print("  response = chat('Follow-up', thread_id='same_thread')")
print("  response = chat('Your question', verbose=True)  # See tool usage")
# Out:
# 🎬 Movie Chatbot Ready!
#
# Usage:
#   response = chat('Your question')
#   response = chat('Follow-up', thread_id='same_thread')
#   response = chat('Your question', verbose=True)  # See tool usage

# %% [markdown]
# ## Test 1: Dynamic URL Fetch (Specific TMDB URL)
#
# Test the new fetch_url_content tool with a specific movie page.

# %%
# Test fetching specific IMDB URL
thread = "test1"

query1 = """Retrieve the following data from the URL https://www.imdb.com/title/tt0113041:
- Title
- Release year
- Genres
- IMDb rating
- Cast & crew
- Awards (if available)"""

print("User:", query1)
print("\n" + "-"*70 + "\n")

response1 = chat(query1, thread_id=thread, verbose=True)
print(f"\nBot: {response1}")
# Out:
# User: Retrieve the following data from the URL https://www.imdb.com/title/tt0113041:
# - Title
# - Release year
# - Genres
# - IMDb rating
# - Cast & crew
# - Awards (if available)
#
# ----------------------------------------------------------------------
#
#
# ======================================================================
# Query: Retrieve the following data from the URL https://www.imdb.com/title/tt0113041:
# - Title
# - Release yea...
# ======================================================================
#   🔧 Using: fetch_url_content
#   🌐 Fetching: https://www.imdb.com/title/tt0113041
#   ✓ Tools used: fetch_url_content
#
# Bot: It seems that the content from the IMDb page for the movie with the ID tt0113041 could not be retrieved due to JavaScript being disabled or a verification requirement on the page. Would you like me to try searching for the movie details using another method? Also, could you please confirm the movie title or provide any other details you know about it?

# %% [markdown]
# ## Test 2: Dynamic URL Fetch (Specific TMDB URL)
#
# Test with a different movie database.

# %%
# Test fetching specific TMDB URL
thread = "test2"

query2 = """Retrieve the following data from the URL https://www.themoviedb.org/movie/11862:
- Genres
- Cast & crew
- Keywords
- Popularity scores
- Overview"""

print("\nUser:", query2)
print("\n" + "-"*70 + "\n")

response2 = chat(query2, thread_id=thread, verbose=True)
print(f"\nBot: {response2}")
# Out:
# User: Retrieve the following data from the URL https://www.themoviedb.org/movie/11862:
# - Genres
# - Cast & crew
# - Keywords
# - Popularity scores
# - Overview
#
# ----------------------------------------------------------------------
#
#
# ======================================================================
# Query: Retrieve the following data from the URL https://www.themoviedb.org/movie/11862:
# - Genres
# - Cast & c...
# ======================================================================
#   🔧 Using: fetch_url_content
#   🌐 Fetching: https://www.themoviedb.org/movie/11862
#   ✓ Tools used: fetch_url_content
#
# Bot: Here is the data retrieved from the URL for the movie "Father of the Bride Part II" (1995):
#
# - Genres: Comedy, Family
# - Cast & Crew:
#   - Director, Screenplay: Charles Shyer
#   - Screenplay: Nancy Meyers
#   - Top Billed Cast:
#     - Steve Martin as George Banks
#     - Diane Keaton as Nina Banks
#     - Martin Short as Franck Eggelhoffer
#     - Kimberly Williams-Paisley as Annie Banks-MacKenzie
#     - George Newbern as Bryan MacKenzie
#     - Kieran Culkin as Matty Banks
#     - BD Wong as Howard Weinstein
#     - Peter Michael Goetz as John MacKenzie
#     - Kate McGregor-Stewart as Joanna MacKenzie
# - Keywords: parent child relationship, baby, midlife crisis, confidence, pregnancy, aging, daughter, sequel, remake, los angeles, california, pregnant woman, contraception, gynecologist, pregnant
# - Popularity scores: Not explicitly listed, but the movie has a UserScore section and a popularity trend graph on the page.
# - Overview: Just when George Banks has recovered from his daughter's wedding, he receives the news that she's pregnant ... and that George's wife is expecting too. He was planning on selling their home, but that's a plan that—like George—will have to change with the arrival of both a grandchild and a kid of his own.
#
# If you want more details or information on another movie, just let me know!

# %% [markdown]
# ## Test 3: Conversation with Memory
#
# Test that memory works across multiple queries.

# %%
# Test conversation memory
thread = "memory_test"

print("\n" + "="*70)
print("Testing Conversational Memory")
print("="*70)

# Query 1
query_a = "Tell me about Christopher Nolan movies"
print(f"\nUser: {query_a}")
response_a = chat(query_a, thread_id=thread)
print(f"Bot: {response_a[:200]}...")

# Query 2 (should remember context)
query_b = "Which one should I watch first?"
print(f"\nUser: {query_b}")
response_b = chat(query_b, thread_id=thread)
print(f"Bot: {response_b[:200]}...")

# Query 3 (still remembers)
query_c = "Why is that one special?"
print(f"\nUser: {query_c}")
response_c = chat(query_c, thread_id=thread)
print(f"Bot: {response_c[:200]}...")
# Out:
# ======================================================================
# Testing Conversational Memory
# ======================================================================
#
# User: Tell me about Christopher Nolan movies
# Bot: Christopher Nolan is a renowned filmmaker known for his complex storytelling, innovative narrative structures, and visually striking films. His movies often explore themes of time, memory, identity, a...
#
# User: Which one should I watch first?
# Bot: To help you decide which movie to watch first, could you please tell me the titles of the movies you're considering? Also, what kind of mood or genre are you in the mood for?...
#
# User: Why is that one special?
# Bot: Could you please specify which movie or topic you are referring to as "that one"? This will help me provide a precise answer about why it might be special....

# %% [markdown]
# ## Test 4: Compare Different Search Methods
#
# See how the different tools work.

# %%
thread = "comparison"

print("\n" + "="*70)
print("Comparing Search Methods")
print("="*70)

# This should use web search for current info
query = "What are the top movies in theaters right now?"
print(f"\nQuery: {query}")
print("Expected tool: search_web (for current info)")
response = chat(query, thread_id=thread, verbose=True)
print(f"\nResponse: {response[:250]}...")

# %% [markdown]
# ## Interactive Testing
#
# Try your own queries!

# %%
# YOUR TURN: Test with your own URL
my_url = "https://www.imdb.com/title/tt0111161"  # The Shawshank Redemption
my_query = f"Get information from {my_url} including title, year, rating, and plot summary"

print(f"User: {my_query}")
response = chat(my_query, thread_id="my_test", verbose=True)
print(f"\nBot: {response}")
# Out:
# User: Get information from https://www.imdb.com/title/tt0111161 including title, year, rating, and plot summary
#
# ======================================================================
# Query: Get information from https://www.imdb.com/title/tt0111161 including title, year, rating, and plot su...
# ======================================================================
#   🔧 Using: fetch_url_content
#   🌐 Fetching: https://www.imdb.com/title/tt0111161
#   ✓ Tools used: fetch_url_content
#
# Bot: It seems that the content from the IMDb page for the movie with the ID tt0111161 could not be retrieved due to JavaScript being disabled on the page. Would you like me to try searching for the information about this movie from other sources? Also, just to confirm, are you looking for details about "The Shawshank Redemption" (which is the movie with this IMDb ID)?

# %% [markdown]
# ## Summary
#
# ### ✅ What We Built:
# - **Three-tool system** for comprehensive movie information
# - **search_web** - Current information and general queries
# - **curated_knowledge_search** - Pre-loaded URLs from Excel
# - **fetch_url_content** - Dynamic URL fetching (NEW!)
# - **Conversational memory** - Maintains context
# - **Thread-based conversations** - Multiple independent chats
#
# ### 🎯 When to Use Each Tool:
# | Tool | Best For | Example |
# |------|----------|---------|
# | **search_web** | Current info, news, general queries | "Top movies this week" |
# | **curated_knowledge_search** | Pre-loaded sources from Excel | General movie database queries |
# | **fetch_url_content** | Specific URLs provided by user | "Get data from https://..." |
#
# ### 🆕 What's New:
# - Can now fetch ANY URL on-demand
# - Perfect for specific IMDB, TMDB, or other movie pages
# - Works alongside existing tools
# - Still maintains conversation memory
#
# ### 📝 Usage Tips:
# 1. **For specific URLs**: Provide the full URL in your query
# 2. **For general info**: Let the agent choose the best tool
# 3. **For memory**: Use same thread_id to continue conversations
# 4. **For debugging**: Use verbose=True to see which tools are used
